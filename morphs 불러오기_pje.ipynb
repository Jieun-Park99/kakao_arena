# %%
morphs =[[]]
with open('data/cleaned_playlist_title.txt') as f:
    for i in range(0,115071):
        for line in f:
            morphs[i].append(line.split(','))
morphs=morphs[0]

# %%
morphs
# Out:
# [['여행', '같', '음악\n'],
#  ['요즘', '너', '말\n'],
#  ['편하', '잔잔', '듣', '있', '곡\n'],
#  ['크리스마스', '분위기', '흠뻑', '취하', '때\n'],
#  ['추억', '노래\n'],
#  ['\n'],
#  ['짝사랑', '고백', '사랑', '이별', '슬픔', '감성', '자극', '곡\n'],
#  ['멍청', '나', '맘', '모르\n'],
#  ['\n'],
#  ['록', '메', '탈', '이일우\n'],
#  ['걸그룹', '때', '쓰쏭\n'],
#  ['노래', '의지', '불태우', '짐', '프로', '필뮤직\n'],
#  ['지치', '너', '위로', '제목', '편지', '준비\n'],
#  ['트렌디', '그루브', '힙합', '알앤비\n'],
#  ['\n'],
#  ['걍', '게임', '하', '때', '듣', '음악\n'],
#  ['나', '알', '노래\n'],
#  ['축가듀엣\n'],
#  ['이렇', '비', '내리', '날', '너', '나', '생각', '하\n'],
#  ['올림픽', '스밍', '목록\n'],
#  ['조용히', '맥주', '한잔', '하', '때', '새벽', '감성\n'],
#  ['ᴡ', 'ᴛɪ', 'ᴊ', 'ᴄ\n'],
#  ['추억', '명화', '만나', '시간', '영화', '모음\n'],
#  ['기분', '좋', '여름날\n'],
#  ['지치', '하루', '끝', '힐', '링', '필요', '당신', '추천', '인디곡\n'],
#  ['새벽', '찬바람', '침대위', '감', '쌀', '때', '국외\n'],
#  ['기분', '좋', '햇살', '같', '숨기', '명곡\n'],
#  ['사랑', '남녀', '듀엣\n'],
#  ['즐기', '듣', '소래\n'],
#  ['닥힙추\n'],
#  ['거', '슈윈', '스타', '워', '즈', '미국', '대표', '클래식\n'],
#  ['겨울', '기다리', '미리', '들\n'],
#  ['아침', '상쾌', '빅', '밴', '드', '스윙스윙\n'],
#  ['여행가', '길', '이런', '음', '악', '함께', '고고씽\n'],
#  ['믿', '듣', '하우스', '일렉트로니카\n'],
#  ['프로', '포', '즈', '음악\n'],
#  ['보', '일본', '곡\n'],
#  ['안다르', '레깅', '스', '입', '운동', '시작\n'],
#  ['발', '라', '드', '감성', '발', '라', '드림', '슬픔주의\n'],
#  ['크리스마스', '책임', '질', '캐롤', '모음\n'],
#  ['아무것', '위', '되', '때', '위로', '되', '음악\n'],
#  ['트렌디\n'],
#  ['우리나라', '라디오', '흘러나오', '명곡\n'],
#  ['영화', '만나\n'],
#  ['우울', '시크\n'],
#  ['극도', '우울', '때\n'],
#  ['폭팔', '밴드', '모음', '집\n'],
#  ['금쪽같', '휴일', '혼자', '시간', '방해\n'],
#  ['\n'],
#  ['여자', '듣', '힙합\n'],
#  ['그', '루브', '넘치', '센스', '있', '음악\n'],
#  ['나', '듣\n'],
#  ['내', '듣', '중화', '노래\n'],
#  ['책', '함께', '편안', '듣', '연주곡\n'],
#  ['이', '달', '인디', '포크\n'],
#  ['가슴', '시리', '사랑', '노래\n'],
#  ['유럽', '여행', '어울리', '팝뮤직\n'],
#  ['사무실', '공기\n'],
#  ['이별', '후', '당신', '마음', '울리', '노래\n'],
#  ['불타', '금요일', '저녁', '더욱', '기분업', '시키', '노래\n'],
#  ['가을', '카페\n'],
#  ['취향', '저격', '앨범아트\n'],
#  ['최대한', '듣', '편하\n'],
#  ['여자', '좋아하', '남자', '노래', '방곡\n'],
#  ['졸음', '운전방지', '댄스', '댄', '플레이리스트\n'],
#  ['연애', '세포', '깨우', '설', '렘', '뿜뿜', '노래\n'],
#  ['천상', '지희', '시간순', '명곡', '좋', '백개이상\n'],
#  ['수능', '시험화이팅', '보컬곡\n'],
#  ['퇴근길', '클래식', '이야기\n'],
#  ['서바이벌', '프로그램', '헤드라이너', '가', '남기', '논쟁\n'],
#  ['\n'],
#  ['도시', '밤', '어울리', '세련', '그루브\n'],
#  ['고속도로', '뚫', '얼른', '듣', '듣\n'],
#  ['이별', '거짓말', '제발가지마\n'],
#  ['포근', '이불속\n'],
#  ['비', '오', '날', '듣', '가슴', '두근두근\n'],
#  ['군산', '쿠바', '클럽', '노래\n'],
#  ['베스트\n'],
#  ['섹', '시', '비트\n'],
#  ['무게', '다르', '해외', '헤비메탈', '모음\n'],
#  ['해변', '드라이브\n'],
#  ['힐', '링', '필요', '신분', '한곡', '한곡', '천천히', '들\n'],
#  ['느낌', '있', '크리스마스', '쏭\n'],
#  ['아무', '때', '듣', '좋', '뉴에이', '지\n'],
#  ['\n'],
#  ['정열', '라', '틴', '음', '악\n'],
#  ['기분', '좋', '음악', '모음\n'],
#  ['가을밤', '풀소리', '함께', '듣', '뉴에이', '지\n'],
#  ['상쾌', '아침', '열', '싱그럽', '뉴에', '지', '음악\n'],
#  ['공통', '감각\n'],
#  ['혼자남', '기', '진밤\n'],
#  ['언제', '효과', '만점인', '매력', '힙합\n'],
#  ['눕', '때', '아무', '생각', '없이\n'],
#  ['편견', '금물', '여름', '끝맺', '니엘', '저스디스', '만남\n'],
#  ['드라이브할때', '신', '나', '곡\n'],
#  ['듣', '다른', '곡', '듣', '되', '마성', '목소리', '모음\n'],
#  ['안구', '촉촉히', '적시', '노래\n'],
#  ['이유', '없이', '센치', '그런', '날', '당신', '들려주', '픈', '노래\n'],
#  ['걸', '그', '룹', '발라드', '명곡', '모음\n'],
#  ['듣', '노래\n'],
#  ['잔잔', '웅장', '락', '들\n'],
#  ['감각', '멜로디', '중독', '있', '비트\n'],
#  ['악동', '서', '울', '런', '쥐', '추천곡\n'],
#  ['\n'],
#  ['흔들리', '벚꽃', '속', '들', '봄', '노래\n'],
#  ['때껄룩', '때껄', '룩', '사랑', '지상', '최고', '플레이리스트\n'],
#  ['자주', '듣', '노래', '목록\n'],
#  ['늦', '밤', '듣', '곡\n'],
#  ['\n'],
#  ['퇴근길', '하루', '마무리', '재즈\n'],
#  ['나', '혼자', '카페', '분위기', '내', '때\n'],
#  ['휴일', '기분', '전환', '어쿠스틱\n'],
#  ['센티멘탈', '플레이리스트', '센치', '분위기', '다', '모이\n'],
#  ['어쿠스틱', '부흥', '선도', '언플러그드', '라이브\n'],
#  ['신해철', '이제', '아픔없', '곳\n'],
#  ['클럽못갈때', '이거', '대리', '만족\n'],
#  ['무덥', '여름', '댓츠노노', '나', '상', '큼', '노래', '시원\n'],
#  ['듣', '좋', '추천곡\n'],
#  ['치명', '치정', '사랑\n'],
#  ['한', '음악', '너무', '따분', '때\n'],
#  ['폭', '풍', '드라이브', '운동', '때', '위하', '극강', '락사운드', '과속주의\n'],
#  ['여돌', '타이틀', '곡', '모음\n'],
#  ['지금', '주목', '인디', '뮤직\n'],
#  ['잠', '안', '오', '때', '듣', '자장\n'],
#  ['영상', '배경음', '매장', '추천\n'],
#  ['일', '렉', '트', '로닉', '한', '들', '너무', '좋\n'],
#  ['매일', '듣', '노\n'],
#  ['듣', '기분', '좋', '가요\n'],
#  ['나', '알', '피아노', '곡\n'],
#  ['감성', '충전', '선율', '아름답', '피아노', '연주곡\n'],
#  ['흥', '겨', '우\n'],
#  ['운동', '아드레', '날리', '폭발\n'],
#  ['주말', '밤', '푹', '잠들', '때', '듣', '수면', '유도', '음악\n'],
#  ['덕후', '모', '여', '랏\n'],
#  ['\n'],
#  ['보', '싸', '다방', '커피', '향기\n'],
#  ['앗', '듣', '더', '신기', '동화\n'],
#  ['새벽', '위하', '노래', '잔잔', '몽', '환\n'],
#  ['아', '나', '연애\n'],
#  ['나', '곡\n'],
#  ['쇼', '미', '더머니', '노래', '모음\n'],
#  ['아침', '활력', '위하\n'],
#  ['가을밤', '니', '생각나', '그런', '밤\n'],
#  ['가을밤', '드라이브할때', '듣', '편하', '곡\n'],
#  ['기타', '들', '노래', '영국', '뮤지션\n'],
#  ['멜로디', '포레', '스', '트', '캠프', '최종', '라인', '업\n'],
#  ['아무', '일단', '신', '나', '노래', '틀\n'],
#  ['혼자', '있', '때\n'],
#  ['비', '오', '날', '감성', '자극', '듣', '좋', '어쿠스틱', '피아노', '발라드\n'],
#  ['이브날', '듣', '그립', '로맨', '틱', '멜로디\n'],
#  ['주말', '도시', '야경', '바라보', '듣', '좋', '노래\n'],
#  ['오늘', '왠지', '꿀꿀', '나', '웃', '클래식', '음악\n'],
#  ['밤', '생각나', '음악\n'],
#  ['여름', '노래', '멜론', '추천\n'],
#  ['그렇', '지나가\n'],
#  ['빌보드', '일자\n'],
#  ['가을', '문턱', '잊', '나', '감성', '깨우', '클래식\n'],
#  ['주말', '힐링', '연주곡\n'],
#  ['가을', '저녁\n'],
#  ['뚫', '뻥', '스트레스', '사라지', '위대', '노래\n'],
#  ['이별', '후', '듣', '더', '슬프', '감성', '발라드', '인디', '노래\n'],
#  ['취존', '수정\n'],
#  ['마음껏', '울', '때\n'],
#  ['귀', '말랑', '인디음악\n'],
#  ['고음병', '걸리', '당', '신', '위하', '명품발라드', '선', '여자', '가수편\n'],
#  ['무현', '반하', '힙\n'],
#  ['사랑', '연인', '잡', '때\n'],
#  ['섹', '시', '발', '언니', '노래\n'],
#  ['빗물', '흐르', '플레이리스트\n'],
#  ['웃', '안녕', '감성', '노래\n'],
#  ['봄', '담', '설', '렘', '가득', '달달', '음악\n'],
#  ['음악', '함께', '산책', '그리고', '행복', '상상\n'],
#  ['크리스', '마스\n'],
#  ['스', '쿨', '오브', '힙합', '초급\n'],
#  ['거짓말', '같', '이별', '이야기\n'],
#  ['놀랍', '주', '은혜\n'],
#  ['일자', '빌보드\n'],
#  ['어디', '가', '힙알', '못', '소리', '듣', '해외\n'],
#  ['자신감', '충전', '파워워킹', '비트', '좋', '음악\n'],
#  ['마커스', '워', '십', '은혜', '받\n'],
#  ['\n'],
#  ['기분', '전환', '필요', '때', '듣', '음악\n'],
#  ['주말', '기다리', '마음', '정화', '노래', '가요', '팝송\n'],
#  ['오직', '기타', '목소리', '이루어지', '감성', '포크\n'],
#  ['달', '새벽', '그리고', '잠', '오', '나\n'],
#  ['민아', '추천곡\n'],
#  ['운동', '듣', '힘나', '빠르', '댄스곡\n'],
#  ['기분', '좋', '하루', '시작', '산뜻', '재즈', '함께\n'],
#  ['심포닉메탈', '넘져\n'],
#  ['정신', '차리', '이미', '댄스', '무아지경', '댄스', '음악\n'],
#  ['사이다', '청량', '톡톡', '터지', '노래\n'],
#  ['나', '성향', '향기\n'],
#  ['\n'],
#  ['욕', '나올정도', '좋', '해외', '알앤비\n'],
#  ['클럽', '홀', '릭', '내한', '공연\n'],
#  ['\n'],
#  ['모음', '집\n'],
#  ['발레', '음악', '클래식', '베스트\n'],
#  ['겨울', '어울리', '감성비트', '특별', '연말', '보내\n'],
#  ['도입', '부', '느낌', '오\n'],
#  ['에너지', '팍팍', '노동요\n'],
#  ['너무', '달달', '귀', '녹아내리', '곡\n'],
#  ['디제잉휘\n'],
#  ['기분', '우울', '때', '힙', '신', '나', '팝송\n'],
#  ['달리\n'],
#  ['오늘', '치', '힘들', '나', '편안', '잠들', '음악\n'],
#  ['도시', '벗어나', '바다', '가', '이', '노래', '틀\n'],
#  ['여름', '명곡', '듣', '당장', '시원', '여름', '노래\n'],
#  ['밤', '듣', '감성', '팝\n'],
#  ['운동', '필요', '당신', '위하', '발레', '음악', '클래식\n'],
#  ['마지막', '주', '퇴근', '플레이리스트\n'],
#  ['소', '울', '태동기', '대중', '다가오', '소울', '대표', '뮤지션\n'],
#  ['믿', '듣', '작사', '작사', '김영후\n'],
#  ['내한', '공연', '예상', '셋', '리', '스', '트\n'],
#  ['선', '버터', '플라이\n'],
#  ['빌보드', '인기', '팝송', '듣', '즐겁\n'],
#  ['\n'],
#  ['이후', '국내', '힙합신', '새롭', '급부상', '뉴페이스들\n'],
#  ['삶', '구석지', '곳', '이야기', '가사\n'],
#  ['\n'],
#  ['나이테', '같', '노래\n'],
#  ['독서', '어울리', '감미', '연주', '음악\n'],
#  ['멜로', '하\n'],
#  ['멜로디', '좋', '미디움템포', '팝', '나른', '커피한', '잔', '하', '때', '필요', '플레이리스트\n'],
#  ['몽환러버', '감성\n'],
#  ['비', '오', '날', '새벽', '듣', '좋', '노래\n'],
#  ['주말', '함께', '하', '힐링', '뮤직\n'],
#  ['봄', '듣', '살랑살랑', '시티팝', '느낌\n'],
#  ['비', '오', '요즘', '기분', '우울\n'],
#  ['목요일\n'],
#  ['후기', '바로크', '세기후', '세기\n'],
#  ['합법', '떨\n'],
#  ['수록', '곡', '반란\n'],
#  ['가을가을', '매장', '음악\n'],
#  ['주간', '인디', '발견\n'],
#  ['라디오\n'],
#  ['크', '러', '시', '원조', '되', '그룹\n'],
#  ['댄', '스', '팝송', '모음\n'],
#  ['봄', '기다리', '듣', '따뜻', '사랑', '노래\n'],
#  ['세련', '스타일', '요즘', '들', '보\n'],
#  ['댄스', '팝', '틀', '신', '나', '춤추', '스트레스', '풀자\n'],
#  ['미리', '메리', '크리스마스\n'],
#  ['진짜', '개띵곡', '모음\n'],
#  ['이센스', '읊조리\n'],
#  ['빌', '보', '드', '차트', '곡', '모음집\n'],
#  ['장르', '퓨쳐베', '이스', '몽롱', '감상', '일', '렉\n'],
#  ['힘들', '때', '마', '음편히', '들', '있', '발라드\n'],
#  ['두', '느낌', '듣', '빠르', '버전\n'],
#  ['비', '오', '날', '듣', '가사', '슬프', '노래\n'],
#  ['듣', '나', '모르', '리듬타', '만들', '노래\n'],
#  ['여름', '방학\n'],
#  ['잠', '오', '밤', '고요', '방', '안', '듣', '노래\n'],
#  ['우리', '카페', '들려주', '크리스마스', '캐럴\n'],
#  ['나', '크레바스\n'],
#  ['잠', '오', '오늘', '밤', '함께', '노래', '모음\n'],
#  ['테크노', '음악\n'],
#  ['빌보드', '선정', '가장', '크', '히트곡', '최고', '곡\n'],
#  ['가을', '듣', '좋', '음악', '무엇\n'],
#  ['쿨', '보내', '아직', '이별\n'],
#  ['부담', '없이', '듣', '좋', '인디음악\n'],
#  ['비트', '짱', '좋', '곡', '모으', '흔하', '팝송', '귀르가즘', '꼬', '우\n'],
#  ['시원', '바다', '그립', '오늘\n'],
#  ['재중', '런칭파티', '패션쇼\n'],
#  ['드라이브', '하', '때', '이', '음악', '틀\n'],
#  ['신', '나', '크리스마스', '어울리', '캐롤', '노래', '준비', '너', '위하\n'],
#  ['출근길', '학교가', '길', '듣', '음악\n'],
#  ['후덥지근', '여름', '밤', '불쾌지수', '낮추', '힐링클', '래식\n'],
#  ['둠칫둠칫', '걷', '때', '듣', '좋', '음악\n'],
#  ['외국펍', '즐기', '느낌', '음악\n'],
#  ['엄선', '명곡', '모으\n'],
#  ['\n'],
#  ['뷰티샵', '듣', '한', '느낌', '패셔너블', '팝\n'],
#  ['\n'],
#  ['음악', '맺', '사랑', '부부', '되', '뮤지션', '대표곡\n'],
#  ['여름', '추천곡', '모음\n'],
#  ['장르', '불문', '내맘', '플레이리스트\n'],
#  ['언제나', '듣', '좋', '젊', '힙합\n'],
#  ['주간', '탄식', '빵\n'],
#  ['부모', '생각', '쓰', '가사', '모음\n'],
#  ['나', '우효\n'],
#  ['이브', '콘서트\n'],
#  ['푸', '르', '밤', '플레이리스트\n'],
#  ['미', '세', '먼', '지', '쌓이', '답답', '날리\n'],
#  ['내', '듣', '저장', '노래\n'],
#  ['라디오\n'],
#  ['기분', '노래\n'],
#  ['밥', '먹', '다니', '밥', '먹', '이', '노래', '듣\n'],
#  ['밤잠', '설치', '당신', '위하', '밤감', '노래\n'],
#  ['겨울', '정취', '느끼', '있', '클래식\n'],
#  ['공부', '하', '때', '집중력', '올리', '주', '클래식\n'],
#  ['운동', '욕구', '상승', '클럽음악', '트레이닝\n'],
#  ['달콤', '음악데이트\n'],
#  ['포크', '싱', '어', '송라이터', '리바이벌\n'],
#  ['요즘', '즐기', '듣', '인디', '노래\n'],
#  ['춥', '겨울', '조용', '새벽', '듣', '노래\n'],
#  ['어둠', '내려앉', '저녁', '듣', '발라드\n'],
#  ['팝씬', '여행', '쿨', '키', '즈', '위하', '안내\n'],
#  ['달콤', '보사노바\n'],
#  ['방탄', '타이틀', '곡', '모음\n'],
#  ['우리', '아이', '재우', '자장', '모', '음\n'],
#  ['길거리', '절대', '듣', '안', '음악\n'],
#  ['뉴에이', '지\n'],
#  ['자유', '행보', '이면', '숨기', '예술\n'],
#  ['재즈', '최신곡', '모음집\n'],
#  ['봄', '오', '소리\n'],
#  ['아이돌', '파헤치\n'],
#  ['가을', '드라이브', '듣', '좋', '노래\n'],
#  ['혼자', '시간', '보내', '듣\n'],
#  ['카페', '흘러나오', '포근', '음악\n'],
#  ['잔디', '초원', '풀잎내음', '양떼', '구름', '목장\n'],
#  ['혼자', '듣', '아깝', '노래', '감성\n'],
#  ['몽글몽글', '샤워', '듣', '적절', '노래\n'],
#  ['감성', '재즈\n'],
#  ['기억속', '잔잔', '발라드\n'],
#  ['운동', '때', '에너지뿜뿜\n'],
#  ['나른', '주말', '오후', '채우', '노래\n'],
#  ['편안', '아침', '열', '팝송\n'],
#  ['우울', '때', '신', '나', '댄스곡\n'],
#  ['라디오', '목', '그', '날', '음악\n'],
#  ['따뜻', '어쿠스틱\n'],
#  ['봄', '듣', '좋', '팝송\n'],
#  ['많', '사람', '알', '하', '노래\n'],
#  ['유튜브', '조회수', '알아보', '핫한', '요즘\n'],
#  ['빌보드\n'],
#  ['위로', '힘들', '지치', '이\n'],
#  ['잠시', '내리', '비', '촉촉', '여름', '오후', '어울리', '음악\n'],
#  ['버스', '안', '듣', '노래\n'],
#  ['흘러가', '편하', '듣', '때\n'],
#  ['달', '달', '여름', '밤\n'],
#  ['그냥', '엄청', '달', '달\n'],
#  ['공부', '수면', '위하', '백색', '소음', '편안\n'],
#  ['아이돌', '컴백', '전쟁', '퀸덤', '원곡모', '음\n'],
#  ['사무실', '플레이리스트\n'],
#  ['도입부', '매력', '인디곡\n'],
#  ['간지녀', '간지남', '들', '듣', '신박', '팝', '가요', '모음\n'],
#  ['둠칫둠칫', '리듬', '저절로', '타지', '팝', '모음\n'],
#  ['내', '좋아하', '노래\n'],
#  ['기쁨\n'],
#  ['퇴근', '길', '귓가', '울리', '퍼지', '뮤직\n'],
#  ['핵인싸', '국내', '힙합', '플레이리스트', '매일업', '데이', '트\n'],
#  ['스티비', '원더', '히트곡\n'],
#  ['꿀꿀', '때', '밝', '자신', '있\n'],
#  ['겨울밤하늘', '바라보', '듣', '몽환송\n'],
#  ['카페', '듣', '좋', '노래\n'],
#  ['힘들', '지치', '때', '힘', '되', '노래\n'],
#  ['발렌타인', '이', '누구', '다가오', '기다리\n'],
#  ['집중', '허전', '때\n'],
#  ['흐리', '바람', '불', '날', '좋아하', '너\n'],
#  ['클럽', '액기스', '드루', '업뎃완료\n'],
#  ['외사랑', '짝사랑', '너', '보내\n'],
#  ['머리', '맑', '부드럽', '뉴에이', '지', '피아노연주곡', '모음\n'],
#  ['재즈', '최신곡', '모음집\n'],
#  ['\n'],
#  ['팝\n'],
#  ['러브숑\n'],
#  ['달', '달', '극치', '플레이리스트\n'],
#  ['몽환', '서정', '노', '이', '즈', '미학', '슈게이', '징\n'],
#  ['이별', '직후', '검색', '추가\n'],
#  ['우주', '소녀', '우정', '만남', '아름답', '노래', '통하', '이루어집\n'],
#  ['테스트', '플레이\n'],
#  ['한국', '전통', '음악', '편견', '깨\n'],
#  ['도입부', '듣', '느낌', '오', '노래\n'],
#  ['듣', '지\n'],
#  ['가을', '사랑', '그', '쓸쓸', '대하\n'],
#  ['주간', '일', '렉', '트', '로', '니카', '라디오', '발매곡\n'],
#  ['피아노', '소리', '너무', '예쁘', '노래\n'],
#  ['신곡', '인디\n'],
#  ['감', '성', '인', '겨울', '발라드\n'],
#  ['잔잔', '이', '밤', '분위기', '좋', '발라드\n'],
#  ['\n'],
#  ['\n'],
#  ['우울', '때', '듣', '더', '우울', '노래\n'],
#  ['선\n'],
#  ['\n'],
#  ['흐리', '날', '선곡', '좋', '주말카페', '들리', '감성', '깊', '멜로디', '보이스라떼\n'],
#  ['매력', '보이스', '남성보컬', '음악\n'],
#  ['외국\n'],
#  ['요즘', '빠지', '노래\n'],
#  ['올드', '팝', '즐기', '연말', '파티\n'],
#  ['너', '나', '시간\n'],
#  ['그', '시절', '그', '노래\n'],
#  ['빌보', '드', '기념', '빌보드', '빛내', '역대', '싱글\n'],
#  ['헤어지', '겨울\n'],
#  ['생각', '정리', '필요', '때', '필요', '피아노', '연주곡\n'],
#  ['오늘', '추천곡\n'],
#  ['마음', '따뜻', '편안', '힐', '링', '재즈\n'],
#  ['콜라', '보', '레이', '션\n'],
#  ['조용', '카페', '어울리', '분위기', '있', '노래', '모음집\n'],
#  ['맞이\n'],
#  ['인디', '듣', '때\n'],
#  ['듣', '기분', '좋', '달콤', '멜로디\n'],
#  ['듣', '신', '나\n'],
#  ['카페', '듣', '좋', '음악', '감성가', '득', '취향', '저격', '피아노연주곡\n'],
#  ['듣', '곡', '가장', '슬프', '발라드', '모음\n'],
#  ['매력', '몽환\n'],
#  ['운동', '때', '듣', '힘', '들', '잊', '되\n'],
#  ['크리스마스', '분위기', '물씬', '나', '곡들', '총집\n'],
#  ['폰부스', '예습', '곡\n'],
#  ['급외로울때', '듣', '기분', '좋', '노래\n'],
#  ['뉴에이', '지', '피아노', '함께', '감성', '시간\n'],
#  ['눈물없', '이', '듣', '없', '슬픔', '발라드\n'],
#  ['잠', '안', '오', '새벽', '나', '대신', '울', '이별', '노래\n'],
#  ['아이', '신', '나', '신체놀이', '시간\n'],
#  ['배경', '음악', '쓰이', '웅장\n'],
#  ['나른', '오후\n'],
#  ['\n'],
#  ['주인공', '부르\n'],
#  ['밤', '듣', '발라드\n'],
#  ['카페', '책', '읽', '때', '나른', '피아노', '연주곡', '함께\n'],
#  ['한', '듣', '하', '노', '래\n'],
#  ['최고', '기타리스트', '그', '밴드', '선보이', '하드록', '헤', '비메탈', '명곡선\n'],
#  ['선곡', '좋', '들리', '달달', '봄', '캐롤송\n'],
#  ['이름', '드러나', '로큰롤', '명예', '전당', '후보\n'],
#  ['트', '렌', '디', '매장', '듣', '좋', '곡\n'],
#  ['간질간', '질', '간절기', '단풍', '단풍', '가을\n'],
#  ['한', '소절', '듣', '빠지', '노래\n'],
#  ['어둡', '새벽', '새까맣', '하늘', '그림', '그리\n'],
#  ['\n'],
#  ['트렌디\n'],
#  ['\n'],
#  ['아이돌', '명곡', '모으\n'],
#  ['빵빵', '떠', '아이돌', '그룹', '명곡\n'],
#  ['누구', '그립', '때\n'],
#  ['\n'],
#  ['명상', '독서', '때', '듣', '클래식\n'],
#  ['무더위', '고생', '당신', '청량', '비트감', '사운드\n'],
#  ['가사', '멜로디', '좋', '국내', '발라드\n'],
#  ['추억', '담기', '노래\n'],
#  ['명품', '남녀', '듀엣곡', '엄선', '곡', '모음\n'],
#  ['나', '귀\n'],
#  ['집중력', '향상', '클래식', '사색', '위하', '클래식\n'],
#  ['개강', '기념', '학생증', '제시', '프리패', '스\n'],
#  ['어리', '시절', '잠결', '흘리', '토요', '명화', '생각나', '영화', '보컬\n'],
#  ['사랑', '잔잔', '경계\n'],
#  ['감미', '피아노', '선율', '재즈곡\n'],
#  ['흥폭팔', '둠', '칫두둠', '칫', '필요', '감각', '팝\n'],
#  ['설', '레', '노래\n'],
#  ['처음', '오', '손', '단골', '매장', '음악\n'],
#  ['비', '오', '날', '감성', '있\n'],
#  ['언더', '커버', '뮤직\n'],
#  ['카페', '듣', '연주곡\n'],
#  ['하루', '마무리', '편안', '음악\n'],
#  ['헤이즈', '모음\n'],
#  ['누에보깐시온', '향기\n'],
#  ['이소라', '기념', '많', '신청곡', '여기', '같이', '들\n'],
#  ['추억', '발라드\n'],
#  ['발라드', '솔로\n'],
#  ['내맘', '사심\n'],
#  ['가을밤', '혼자', '생각', '잠기', '때\n'],
#  ['감성', '폭발\n'],
#  ['외로움', '달래', '가사', '없', '연주', '음악', '특선\n'],
#  ['남녀', '듀엣곡', '아름답', '곡\n'],
#  ['북카페', '울리', '퍼지', '잔잔', '음', '악\n'],
#  ['상반기', '나의소울\n'],
#  ['잔잔', '노래', '듣', '때\n'],
#  ['여름', '오', '들썩들썩\n'],
#  ['요즘', '참', '몽환', '음악', '끌리\n'],
#  ['신', '나', '금요일', '우리', '오늘', '해\n'],
#  ['퇴근길', '다소', '멜랑', '리', '잠깐', '밟\n'],
#  ['청각', '미각', '신', '맛\n'],
#  ['명품', '명품', '골든', '발라드\n'],
#  ['가을밤', '듣', '좋', '노래\n'],
#  ['감각', '세련', '매장\n'],
#  ['겨울', '듣', '인디', '팝\n'],
#  ['방해', '받', '나', '위하', '휴가', '음악\n'],
#  ['\n'],
#  ['아티스트', '추천', '테스트', '따옴표\n'],
#  ['헬스장', '운동', '때', '듣', '좋', '누구', '신', '나', '노래\n'],
#  ['듣', '듣', '좋', '분위', '기갑', '아이돌', '명곡\n'],
#  ['잔잔', '신남', '그', '사이', '어디\n'],
#  ['오리지날', '버전', '어쿠스틱', '버전\n'],
#  ['머리', '맑', '기분', '좋', '뉴에이', '지\n'],
#  ['\n'],
#  ['여름', '밤', '잔디밭\n'],
#  ['팝송', '몇몇', '좋', '곡', '고르', '보\n'],
#  ['여름', '어울리', '시원상쾌\n'],
#  ['\n'],
#  ['오늘', '혼자', '시간', '필요\n'],
#  ['가을', '여행', '함께', '하', '낭만', '재즈\n'],
#  ['광고', '음악', '어울리', '감각', '음악\n'],
#  ['가을', '밤', '어울리', '감성보컬', '알앤비', '모음\n'],
#  ['고장난', '라디오', '오후\n'],
#  ['가을동화', '나', '삶', '눈물', '채우', '그', '립', '음악\n'],
#  ['연애초기', '달달', '설레', '설레', '노래\n'],
#  ['나', '가수', '차', '미리', '듣\n'],
#  ['그대\n'],
#  ['노래', '모음\n'],
#  ['카푸치노', '음악', '한', '방울\n'],
#  ['보통날\n'],
#  ['듣', '노래\n'],
#  ['따뜻', '커피', '한잔', '음악', '한조각\n'],
#  ['눈', '감', '듣', '힐링', '음악\n'],
#  ['수면제', '대신', '이', '노래', '듣', '잠', '들\n'],
#  ['뉴욕', '가을도시', '낭만\n'],
#  ['기분', '좋', '하루', '나', '힘나', '노래\n'],
#  ['테스타먼트', '거치', '가', '드', '러머', '환상', '명연주\n'],
#  ['한', '들어보', '추천곡', '모음집\n'],
#  ['옥타곤', '내한', '마티스', '사드코\n'],
#  ['밴드음악', '듣\n'],
#  ['너', '선물', '음악', '꽃\n'],
#  ['코첼라', '페스티벌', '강력', '일', '렉트', '로', '닉', '음악', '페스티벌', '되', '있', '이유\n'],
#  ['톡톡', '튀', '몽', '환곡\n'],
#  ['남자', '아이돌', '노래', '모음\n'],
#  ['걸그룹', '발라드', '명곡\n'],
#  ['가을', '끝', '잔잔', '음악', '필요', '때\n'],
#  ['드라마', '끝나', '남\n'],
#  ['조금', '남다르', '음악', '박자\n'],
#  ['서울재즈', '페스티벌\n'],
#  ['월요병', '이기\n'],
#  ['어서', '오', '힐링곡', '맛집입니', '당\n'],
#  ['춥', '겨울', '따뜻', '손난로', '같', '고막', '남여친', '감성', '노래\n'],
#  ['가만히', '눕', '듣', '오후', '피크닉\n'],
#  ['터보', '종국', '근육맨\n'],
#  ['조용필\n'],
#  ['마음', '정화\n'],
#  ['무한도전', '위대', '유산\n'],
#  ['드라브', '조용', '강변', '카페', '커피한잔', '하', '잔잔', '음악', '함께\n'],
#  ['노래', '만나', '재즈', '스탠더드\n'],
#  ['\n'],
#  ['산책', '때', '듣', '적당히', '흥나\n'],
#  ['또', '한', '여름', '오\n'],
#  ['나', '모르', '들썩거리', '노래\n'],
#  ['쇼미', '더', '머니', '프로듀서', '스페셜', '코드', '쿤스트', '팔로알토\n'],
#  ['니드', '포', '스피드', '엣지\n'],
#  ['아메리카', '노', '한', '잔', '가볍', '출근길\n'],
#  ['일요일', '드라이브', '하', '듣', '딱', '좋', '노래\n'],
#  ['집', '있', '집', '가', '때', '찾', '듣\n'],
#  ['오늘', '추천곡\n'],
#  ['따듯', '욕조', '신욕', '듣', '힐링', '음악\n'],
#  ['첫', '소절', '듣', '느낌', '오', '곡\n'],
#  ['센치', '때', '듣', '딥한', '감성', '팝\n'],
#  ['여름', '여행', '분위기\n'],
#  ['익숙\n'],
#  ['일', '렉', '트로', '니', '카', '파생', '랩', '음악\n'],
#  ['그', '날', '좋', '곡', '발행\n'],
#  ['클럽', '인트', '플레이리스트\n'],
#  ['흑', '인스멜', '코', '리안', '뮤직', '탄\n'],
#  ['요즘', '가장', '핫', '하', '일렉', '팝', '아주', '그냥\n'],
#  ['뉴에', '지', '신', '곡', '모음집\n'],
#  ['갈매', '기공', '화국', '알\n'],
#  ['피아노', '첫', '걸음', '바이엘', '연습곡\n'],
#  ['가수바', '기', '베스트\n'],
#  ['머리맡', '틀', '자기', '좋\n'],
#  ['한', '들어', '필수', '팝송', '모음\n'],
#  ['올해', '록', '앨범', '국내', '국외\n'],
#  ['매', '일', '들', '질리', '스테디셀러', '같', '노래\n'],
#  ['썸', '데이트', '때', '듣', '재즈\n'],
#  ['사랑', '시작', '설레임\n'],
#  ['여름', '시원', '댄스', '음악\n'],
#  ['달콤', '노래\n'],
#  ['잠들', '전', '편안', '듣', '클래식음악\n'],
#  ['불면증', '특효약', '여름밤', '듣', '좋', '노래\n'],
#  ['조용히', '혼자', '듣', '때', '네엣\n'],
#  ['\n'],
#  ['아련', '봄', '오', '봄향기', '느끼', '노래\n'],
#  ['서울재즈페', '스티벌\n'],
#  ['발라드', '모음', '공간', '입\n'],
#  ['지나가', '지나가', '위로', '되', '노래\n'],
#  ['이별', '시작\n'],
#  ['차안', '듣', '좋', '노래\n'],
#  ['걸', '그룹', '여름', '히트곡\n'],
#  ['퇴근길', '듣', '만', '플레이리스트\n'],
#  ['일자', '독일', '싱글', '차트\n'],
#  ['다시', '봄', '뭐', '설레', '요즘', '감성', '더', '촉촉', '만들', '노래\n'],
#  ['새벽', '혼자', '너', '생각\n'],
#  ['달콤', '힙합', '다정', '발라드\n'],
#  ['프', '레', '시업\n'],
#  ['피아노', '기타', '어우르', '어쿠스틱', '음악\n'],
#  ['어느', '멋지', '가을날\n'],
#  ['\n'],
#  ['주관', '한국', '아이돌', '명곡', '모음', '추천', '받\n'],
#  ['환상', '케미스트리\n'],
#  ['\n'],
#  ['친구', '함께', '동화', '들\n'],
#  ['카페', '듣', '좋', '음악\n'],
#  ['출근길', '활기차', '만들', '노래\n'],
#  ['봄', '듣', '크리스마스', '송\n'],
#  ['\n'],
#  ['밤하늘', '별', '수놓', '국내', '모\n'],
#  ['래', '퍼', '감성', '느끼', '띵곡들\n'],
#  ['조용조용', '방탄', '소년단\n'],
#  ['\n'],
#  ['달달', '노래', '임시', '저장\n'],
#  ['새벽', '듣', '좋', '감성', '노래', '모음\n'],
#  ['여자', '아이돌', '히트곡', '모음', '걸그룹', '여돌', '솔', '로\n'],
#  ['국내', '감성', '모음\n'],
#  ['트와이', '스', '국민', '걸그룹', '만들', '블랙아이드', '필', '승\n'],
#  ['이', '주의', '마지막주\n'],
#  ['아무', '로', '나', '미\n'],
#  ['커피', '찰떡궁합', '알', '앤비', '힙합\n'],
#  ['공부', '때', '가볍', '듣', '음악\n'],
#  ['가을', '노래\n'],
#  ['똑', '똑', '겨울', '노래', '도착입니닷\n'],
#  ['이', '노래', '진', '짜', '섹', '시\n'],
#  ['어둡', '밝', '푸르', '새벽', '같', '곡\n'],
#  ['신', '나', '리', '드미컬', '노래', '원하', '당장', '클릭\n'],
#  ['카페', '힐링', '듣', '노래', '카페', '힐링\n'],
#  ['노래틀고', '울\n'],
#  ['멋', '취향', '저격', '과하', '신나', '사운드\n'],
#  ['한', '듣', '하루동안', '신', '나', '노래\n'],
#  ['숙면', '연애', '세포', '깨우', '노래\n'],
#  ['자기', '전', '듣', '좋', '따뜻', '목소리\n'],
#  ['따뜻', '봄날', '외출', '위하', '얼터너티브', '팝\n'],
#  ['올', '크리스마스', '캐롤\n'],
#  ['달콤', '살', '벌', '썸', '남', '썸녀', '노래\n'],
#  ['팝스타', '한국어', '패치', '완료', '수시', '업데이트\n'],
#  ['비오', '들', '매장', '마감곡\n'],
#  ['\n'],
#  ['듣어\n'],
#  ['운동', '할때\n'],
#  ['피아니스트', '명', '모음\n'],
#  ['오', '같', '느낌', '주\n'],
#  ['나', '고막', '책임지', '계속', '듣', '되', '달', '달', '구리', '노래\n'],
#  ['아무', '일', '없', '듣', '감성', '터지', '음악\n'],
#  ['이', '노래', '듣', '가을', '냄새', '느끼\n'],
#  ['일자', '프랑스', '싱글', '차트\n'],
#  ['어', '린시절', '추억', '만화', '영화주제곡', '베스트\n'],
#  ['잠들', '전', '연인', '들려주', '달콤', '자장\n'],
#  ['살', '한', '꼭', '듣', '되', '베토벤', '작품\n'],
#  ['지나', '기억', '누구', '그립', '때\n'],
#  ['운동', '때', '힙한', '느낌', '가득', '챙기', '감각', '신', '나', '팝\n'],
#  ['아름답', '알앤', '비', '힙합\n'],
#  ['\n'],
#  ['모든', '다', '내려놓', '때', '듣', '눈물', '나', '노래\n'],
#  ['주말', '휴식', '위하', '뉴에이', '지', '피아노', '음악\n'],
#  ['공개', '리스닝', '세션', '후기\n'],
#  ['한국', '힙합', '단체곡\n'],
#  ['새벽', '감', '촉촉\n'],
#  ['좋아하', '인디\n'],
#  ['팬텀싱어', '원곡\n'],
#  ['방탄', '소년단', '함께\n'],
#  ['리듬', '마라톤\n'],
#  ['빌보드', '일자\n'],
#  ['일렉빠', '모음', '집\n'],
#  ['추천', '입\n'],
#  ['점수', '묻', '떠블', '로', '가', '수능대박', '응원', '위로', '메시지\n'],
#  ['노래', '부르', '때', '모음', '항상업뎃중\n'],
#  ['\n'],
#  ['무인', '가', '때', '가져가', '진짜', '발라드', '명곡\n'],
#  ['겨울', '공기', '머금', '몽환', '인디', '뮤직', '선\n'],
#  ['노창', '울', '가', '진짜', '미치', '곡', '모으\n'],
#  ['잠들', '밤', '잔잔', '듣', '있', '음악\n'],
#  ['가사', '공감', '노래\n'],
#  ['우울', '나락\n'],
#  ['중년', '나이트댄스곡\n'],
#  ['너', '목소리', '들리', '번외편\n'],
#  ['요즘', '듣', '어쿠스틱', '발라드\n'],
#  ['듣', '재미', '있', '피아노', '협주곡\n'],
#  ['자연', '소리', '심리', '안정', '위하\n'],
#  ['음악디자이', '너', '취향', '저격', '좋', '노래\n'],
#  ['\n'],
#  ['뉴', '에', '이', '지', '함께', '좋', '아침', '열\n'],
#  ['청량', '시원', '노래', '드라이브곡', '여름\n'],
#  ['\n'],
#  ['추천', '한', '여름', '밤', '발라드', '①\n'],
#  ['겨울', '끝', '봄', '기다리', '듣', '잔잔', '산뜻', '감성', '팝\n'],
#  ['기타소리', '좋', '노래\n'],
#  ['여름', '밤', '선선', '감성', '목소리', '전달', '노래\n'],
#  ['한국노', '래', '좋', '노래\n'],
#  ['요즘', '잘', '모르', '노래\n'],
#  ['노이즈', '공간감', '만들', '몽롱', '슈', '게', '이', '징\n'],
#  ['우리', '집', '흐르', '포근', '피아노', '음악\n'],
#  ['애정', '상징', '플레이리스트\n'],
#  ['나', '안', '감정', '우울\n'],
#  ['재즈\n'],
#  ['열\n'],
#  ['상큼', '락', '하루\n'],
#  ['쉽', '편하', '듣', '있\n'],
#  ['\n'],
#  ['가끔', '발라드\n'],
#  ['신', '나', '유로팝\n'],
#  ['바람', '불', '야외', '듣\n'],
#  ['신화', '추억\n'],
#  ['겨울', '지나오', '듣', '따스', '어쿠스틱\n'],
#  ['추천', '곡곡\n'],
#  ['위클리초이스\n'],
#  ['감성', '그', '이름의노래\n'],
#  ['돌아가\n'],
#  ['\n'],
#  ['흥', '돋우\n'],
#  ['겨울', '감성', '터지', '이별', '발라드', '노래방', '선곡\n'],
#  ['뉴이스', '트', '최애곡\n'],
#  ['노래\n'],
#  ['나', '시각', '청각', '훔치\n'],
#  ['팬\n'],
#  ['내', '뽑', '모음\n'],
#  ['춥', '날', '듣', '더', '좋', '노래', '같이', '들\n'],
#  ['오렌지', '빛', '하늘', '드리울', '때', '황홀', '드라이브', '위하', '시티', '팝\n'],
#  ['알앤비', '땡기', '지금', '금금금\n'],
#  ['듣', '좋', '세기말', '한국', '음악\n'],
#  ['아직', '성장\n'],
#  ['감성', '필충', '힙합\n'],
#  ['\n'],
#  ['두둠칫', '흥', '절', '로', '돋', '음악', '모으\n'],
#  ['이스케이', '프', '코리아', '라인업', '발표\n'],
#  ['퇴근', '길', '함께', '따뜻', '발라드\n'],
#  ['클래식', '신', '곡', '모음집\n'],
#  ['듣', '순간', '가볍', '그루브', '타', '되', '노래\n'],
#  ['당신', '기분', '하', '껏', '올리', '주\n'],
#  ['나는노래\n'],
#  ['추억', '돋', '영혼', '있', '노래\n'],
#  ['감성', '젖', '있', '과거', '최고', '국내', '국외', '락발라드', '모음\n'],
#  ['클럽', '에덴', '맞', '이\n'],
#  ['캐주얼', '레스토랑\n'],
#  ['태', '연', '정규', '앨범\n'],
#  ['너', '지금', '뭐', '해', '자\n'],
#  ['힘', '좀', '내', '신', '나', '국내', '락\n'],
#  ['감수', '자극', '봄비', '오', '때', '생각', '많', '때', '듣', '좋', '피아노', '연주곡\n'],
#  ['혼자', '듣', '아', '깝', '음악\n'],
#  ['부활\n'],
#  ['개인', '플레이리스트\n'],
#  ['매장', '듣', '노래\n'],
#  ['평생', '듣', '질', '리\n'],
#  ['나', '맘대로', '상반기\n'],
#  ['무더위', '날리', '시원', '여름', '가요', '모음\n'],
#  ['띵곡', '모음집\n'],
#  ['알', '사람', '다', '알', '느낌', '있', '팝\n'],
#  ['멍때리\n'],
#  ['비', '오', '날', '잔잔', '느끼\n'],
#  ['일본', '노래', '모음\n'],
#  ['감성', '발라드\n'],
#  ['라디오\n'],
#  ['내적', '댄스', '유발', '곡\n'],
#  ['소울', '어쿠스틱', '합치\n'],
#  ['\n'],
#  ['뮤직테라피', '스테디\n'],
#  ['차안', '분위기', '있', '듣', '노래\n'],
#  ['중복', '비', '오', '무조건', '신', '나', '음악', '함께\n'],
#  ['짬', '나오', '세대', '힙합', '래퍼\n'],
#  ['룸', '좋아하', '더', '많', '감성', '힙합\n'],
#  ['불후', '명곡', '전설', '노래', '특집', '김수철', '원곡\n'],
#  ['지브리', '애니메이션', '명곡', '만나', '피아노', '지브리', '콘서트\n'],
#  ['듣', '전투력', '상승', '곡', '외', '힙', '위주\n'],
#  ['한', '듣', '노래\n'],
#  ['집중', '작업', '도움이', '되', '음악\n'],
#  ['베이스', '사운드', '오', '지', '곡\n'],
#  ['\n'],
#  ['인가구', '살\n'],
#  ['분위기', '있', '비트', '음악', '함께', '하루', '만들\n'],
#  ['감', '성자', '극', '음악', '모음\n'],
#  ['울', '웃', '잔', '잔한노래\n'],
#  ['\n'],
#  ['취향타\n'],
#  ['내', '좋아하', '노래', '너', '좋아하', '하', '노래\n'],
#  ['카페', '새벽', '듣', '무', '있', '노래\n'],
#  ['새벽', '우울', '때', '듣', '우울', '끝', '노래\n'],
#  ['고백', '좋', '날\n'],
#  ['무더위', '듣', '시원', '느낌\n'],
#  ['귓가', '자꾸', '맴돌', '달달', '러브', '송\n'],
#  ['달콤', '달달', '로맨틱', '노래\n'],
#  ['비', '오', '날', '우울', '마음', '달래', '노래', '모음\n'],
#  ['청량감', '여름', '저격', '댄스곡\n'],
#  ['꽃길', '입맞춤', '달콤', '분위기', '장르불문', '분위기', '띄우\n'],
#  ['클럽', '일', '렉트로닉\n'],
#  ['그래미', '어', '워', '즈', '컨', '츄리', '가', '스펠', '부문', '후보곡\n'],
#  ['가슴', '뭉클\n'],
#  ['\n'],
#  ['금요일', '비', '오', '그치', '날씨', '이상\n'],
#  ['응팔', '모음', '집\n'],
#  ['아무', '좋아하', '노', '래\n'],
#  ['듣', '곡', '없', '같', '밤', '듣', '곡\n'],
#  ['살\n'],
#  ['리드', '미컬\n'],
#  ['목요일', '그냥', '왠지', '싫\n'],
#  ['감성', '있', '는밤\n'],
#  ['인생', '바꾸', '있', '시점', '너', '위로', '계속', '추가\n'],
#  ['커피', '마시', '조용히', '듣', '좋', '노래\n'],
#  ['다양', '맛', '찾아오', '빨간', '고추\n'],
#  ['요즘', '푹', '빠지', '곡\n'],
#  ['아련', '옛', '드라마', '모', '음\n'],
#  ['사랑', '혹은', '슬프', '이별', '가슴', '남기\n'],
#  ['조금', '선선', '밤', '걷', '듣', '좋', '노래\n'],
#  ['진', '토닉', '함께', '듣', '음악\n'],
#  ['\n'],
#  ['아침', '활력', '위하', '재즈\n'],
#  ['듣', '좋', '뉴에이', '지', '음악\n'],
#  ['좋\n'],
#  ['이소라', '명곡', '집\n'],
#  ['멜론', '좋', '수', '이상', '곡들\n'],
#  ['올', '여름', '일렉', '파도', '밀려오\n'],
#  ['호', '주차트\n'],
#  ['무덥', '여름', '청량감', '더', '플레이리스트\n'],
#  ['새벽', '듣', '잠', '잘', '오', '노래\n'],
#  ['오래', '드라마\n'],
#  ['리드미', '컬', '느낌', '좋', '느낌\n'],
#  ['나', '날', '보내', '때\n'],
#  ['ఇ', '벅차', '오르', '숨', '여돌', '명곡\n'],
#  ['요요마곡\n'],
#  ['워너', '재결성\n'],
#  ['멜로디', '포레', '스', '트', '캠프', '주요', '라인업\n'],
#  ['루키', '행보', '기대', '신예', '아티스트\n'],
#  ['사랑', '왠지', '끌리', '노래\n'],
#  ['완전', '감동', '음악\n'],
#  ['봄', '오\n'],
#  ['달달\n'],
#  ['사랑', '이', '함께', '있\n'],
#  ['마약', '같', '씨잼', '싱잉랩\n'],
#  ['혼자', '시간', '편안', '무드', '베드룸', '팝\n'],
#  ['가슴', '전율', '일', '렉', '트로니카', '세계\n'],
#  ['\n'],
#  ['힙잘알', '되', '주차', '비프', '리\n'],
#  ['공부', '때', '듣', '편안', '음악\n'],
#  ['혼자', '끄덕끄덕\n'],
#  ['따뜻', '봄저녘', '듣', '힐', '링가득찬', '음색\n'],
#  ['가사', '꼭', '나', '얘기\n'],
#  ['아이돌', '숨', '명곡\n'],
#  ['태교', '음악', '사랑', '우리', '아이', '위하', '자장', '가음악\n'],
#  ['여름', '휴가', '가', '차안', '듣', '좋', '노래\n'],
#  ['나', '고막', '책임', '여성', '솔로', '아티스트\n'],
#  ['잃\n'],
#  ['뉴에', '지', '신', '곡', '모음집\n'],
#  ['덥', '여름', '그대', '시원', '노래\n'],
#  ['감성보컬', '알', '앤비', '좋', '밤', '되\n'],
#  ['\n'],
#  ['진정', '울림\n'],
#  ['오늘', '서', '글', '픔\n'],
#  ['부드럽', '뉴에이지', '듣', '쉬\n'],
#  ['크리스마스', '앞두', '아이돌', '겨울', '노래\n'],
#  ['내', '좋아하', '래퍼', '지심\n'],
#  ['달달', '터지', '외로움', '터', '지', '같', '인디음악\n'],
#  ['\n'],
#  ['마', '성', '목소리', '수록', '곡\n'],
#  ['비', '커피', '추억', '잔', '잔', '노', '래\n'],
#  ['사랑', '관하', '설', '렘', '가득', '피아노', '힐링', '음악\n'],
#  ['후', '입김', '나오', '시작', '춥', '겨울', '따스', '노래', '듣', '이겨내\n'],
#  ['한강', '바라보', '릴렉스\n'],
#  ['\n'],
#  ['크리스마스', '맞이\n'],
#  ['\n'],
#  ['여유', '필요', '당신', '건네', '감미', '재즈', '팝\n'],
#  ['\n'],
#  ['알', '말듯', '네', '마음', '궁금\n'],
#  ['비', '오', '날', '듣', '필청곡\n'],
#  ['인디음악', '소화', '가장', '쉽', '방법\n'],
#  ['거장', '클린트', '이스트우드', '감독', '영화', '음악', '세계\n'],
#  ['이소라', '두', '프로', '포즈\n'],
#  ['볼빨', '간사춘기', '안지영', '생일\n'],
#  ['\n'],
#  ['무더위', '한', '날리\n'],
#  ['나', '애곡', '모음\n'],
#  ['숨', '명곡', '대신', '찾아', '리\n'],
#  ['모두', '다', '알', '한', '다', '시듣', '노래\n'],
#  ['사랑', '받', '곡모음\n'],
#  ['빌보드차트', '취향', '저격\n'],
#  ['파워', '풀', '가창력', '소유자', '내한', '예상', '세트리스트\n'],
#  ['이', '정도', '재즈', '충분\n'],
#  ['여름', '밤', '바람', '불', '카페', '듣', '노래\n'],
#  ['록', '춤', '추', '있\n'],
#  ['당신', '맘', '밤', '적시', '감성', '힙합\n'],
#  ['겁크', '파이', '팅\n'],
#  ['국내', '힙스타일\n'],
#  ['고개', '까닥', '까닥', '듣', '좋', '노래\n'],
#  ['디제', '이', '플레이\n'],
#  ['워너', '에센셜', '제스', '글린\n'],
#  ['무도가', '요제', '후보\n'],
#  ['나', '중', '병', '락', '심취\n'],
#  ['중독', '강', '노래\n'],
#  ['연애', '세포', '자극', '달달', '남녀', '듀엣', '곡\n'],
#  ['랩', '모르', '사람', '재즈', '들\n'],
#  ['\n'],
#  ['퇴근길', '발', '라드', '취하\n'],
#  ['사랑', '가득', '노래\n'],
#  ['락발라드\n'],
#  ['그루', '브', '넘치\n'],
#  ['오래', '최신', '알', '사람', '알\n'],
#  ['음악', '세계', '기말\n'],
#  ['이갈룡폴더\n'],
#  ['어쿠스틱', '달다랗', '노래\n'],
#  ['\n'],
#  ['겨울', '봄', '사이', '어디\n'],
#  ['가을', '발라드', '감성', '샷추가', '음색', '시', '럽추', '하', '듣어\n'],
#  ['시대', '차별', '없', '인싸곡', '노래', '모음\n'],
#  ['네', '오', '하', '카페', '너', '너\n'],
#  ['위하', '노래', '선\n'],
#  ['사랑', '이름', '교집합\n'],
#  ['마음', '안정', '클래식\n'],
#  ['늦', '봄', '이별후\n'],
#  ['분위기', '끝나', '노래\n'],
#  ['나', '감성', '음악\n'],
#  ['조용히', '심연', '깊이', '울리', '여', '운\n'],
#  ['리', '메이', '크', '드라마\n'],
#  ['차타', '달리', '때\n'],
#  ['기억', '망각', '이동진', '의', '꿈', '다방', '라디\n'],
#  ['\n'],
#  ['정미', '애', '팬분', '스밍', '용', '기초교류\n'],
#  ['비', '어울리', '감성', '힙합', '드랍', '더', '비트\n'],
#  ['매장', '쓰', '수', '있', '신나', '음악\n'],
#  ['드라마', '속', '분위기', '녹아들\n'],
#  ['덥', '지', '마음', '시원\n'],
#  ['이별', '하', '울', '되\n'],
#  ['푸르', '바다', '남자', '이별', '이야기\n'],
#  ['특별', '주말', '특별\n'],
#  ['음악', '오타쿠', '분위기', '오타쿠', '듣', '위하\n'],
#  ['사로잡', '패밀리', '그룹\n'],
#  ['봄', '듣', '좋', '상큼', '달달', '경쾌', '발랄', '음악\n'],
#  ['무슨', '뜻', '숫자', '제목', '노래\n'],
#  ['안예', '곡\n'],
#  ['멜로디\n'],
#  ['두', '도란도', '란\n'],
#  ['여름', '댄스\n'],
#  ['이노래', '그때', '그', '노래\n'],
#  ['제이팝', '여왕', '하마사키', '아', '유', '미\n'],
#  ['클럽', '타', '자', '보아일랜드', '루루루', '진', '달', '래', '밴드', '문패트롤\n'],
#  ['신', '나', '크리스', '마스\n'],
#  ['미국차트\n'],
#  ['가을', '머금', '카페', '뮤직\n'],
#  ['새롭', '물결', '얼터너티브\n'],
#  ['오지', '지리', '팝', '락각', '겨울', '여행\n'],
#  ['어디', '들어보', '없', '재즈', '모음\n'],
#  ['트와이스', '일본', '타이틀', '곡', '모음\n'],
#  ['외국', '힙합\n'],
#  ['느낌', '있', '음악\n'],
#  ['눈물', '나', '얘기\n'],
#  ['베리베리', '해피', '메리', '크리스마스\n'],
#  ['태교', '좋', '노래\n'],
#  ['뽀글뽀글', '노래', '듣어\n'],
#  ['\n'],
#  ['이', '노래', '가을', '가을', '느끼', '시작', '때', '듣', '노래\n'],
#  ['아버지', '어머니', '바치', '노래\n'],
#  ['나', '위로', '필요\n'],
#  ['달달', '재즈', '플레이리스트\n'],
#  ['감성', '힙합\n'],
#  ['향기', '가득', '매장', '위하', '뉴에이', '지\n'],
#  ['신', '나', '댄스곡\n'],
#  ['혼자', '시간', '채우', '따스', '팝\n'],
#  ['이별후', '마음', '정리', '위하', '감성', '음악\n'],
#  ['하루', '마무리', '듣', '편안', '곡\n'],
#  ['역대', '쇼미더머니', '음원', '모음\n'],
#  ['푸르', '바', '다', '의전설', '도깨비\n'],
#  ['설', '레임', '인디사운드\n'],
#  ['감각', '트렌디', '유니크', '노래\n'],
#  ['잔잔', '듣', '좋', '곡\n'],
#  ['올드', '힙합\n'],
#  ['가사', '은근히\n'],
#  ['발라드', '모음\n'],
#  ['겨울', '감성', '진하', '묻어나', '포근', '보이', '스라', '떼', '로맨', '틱', '멜로디\n'],
#  ['시원', '가을', '밤', '드라이브', '즐기', '듣', '음악\n'],
#  ['로보트', '주인공', '노래\n'],
#  ['새벽길', '잔잔', '감성', '리스트\n'],
#  ['하', '너무', '아깝', '명곡\n'],
#  ['걸', '그룹', '아이돌', '히트곡', '모음\n'],
#  ['시대', '차트', '국내', '차트\n'],
#  ['비투비', '각', '앨범', '좋', '수록', '곡\n'],
#  ['디', '사', '이', '저', '베이비\n'],
#  ['비', '오', '날', '어울리', '잔잔', '느끼\n'],
#  ['너무', '춥', '날씨', '감성', '발라드', '따뜻\n'],
#  ['애니메이션', '명곡\n'],
#  ['학교', '가', '길', '기분', '좋', '살랑', '살랑', '힙한', '인디', '노래\n'],
#  ['\n'],
#  ['젊음', '가요제', '입상곡\n'],
#  ['여름', '드라이브', '여행', '때', '듣', '좋', '상큼', '발랄', '신', '나', '노래', '업뎃', '수정\n'],
#  ['유럽', '음악', '모음\n'],
#  ['늦', '밤', '나', '감성', '깨우', '취향', '저격', '음악\n'],
#  ['내', '요즘', '듣', '노래', '같이', '듣\n'],
#  ['힘들', '때', '혼자', '듣', '좋', '음악\n'],
#  ['미국식', '토종', '힙합\n'],
#  ['도입', '부', '사로잡\n'],
#  ['아무', '생각', '없이', '듣', '좋', '노래\n'],
#  ['슬프', '때', '함께', '울', '힙합\n'],
#  ['마음', '맑', '힐링', '뉴에이', '지\n'],
#  ['러브라', '추리게임', '하트시그널', '시즌\n'],
#  ['한', '듣', '보', '오래전', '팝송', '바로', '그거\n'],
#  ['이국', '느낌', '좋', '음악\n'],
#  ['웨딩', '듣', '하', '결혼', '웨', '딩', '송\n'],
#  ['성\n'],
#  ['머릿속', '맴돌', '멜로디', '중독', '짱\n'],
#  ['라이브아', '미', '주', '플레이리스트\n'],
#  ['나', '알', '리스', '트\n'],
#  ['봄', '날', '멜', '랑콜리아', '색다르', '인디\n'],
#  ['상큼', '큼', '공감', '노래\n'],
#  ['멜론', '인기곡', '가요\n'],
#  ['렬루', '곡', '탄\n'],
#  ['댄스2\n'],
#  ['요즘', '많이', '듣', '곡\n'],
#  ['잠자', '듣', '좋', '퓨전', '국악\n'],
#  ['흐리', '가을', '하늘', '쓰', '음악', '편지\n'],
#  ['심쿵', '곡', '모음\n'],
#  ['\n'],
#  ['슬프', '이별', '발라드', '노래', '곡\n'],
#  ['함께', '듣', '노래\n'],
#  ['일자', '싱글', '차트\n'],
#  ['잔차', '라이딩', '음악\n'],
#  ['나', '새봄\n'],
#  ['운동', '끝', '록', '음악', '상쾌', '홈트\n'],
#  ['클래식', '음악', '매력', '속\n'],
#  ['어쩌면', '우리', '첫', '클래식\n'],
#  ['라디오', '청취자', '오랜', '사랑', '받', '대중가요\n'],
#  ['오페라', '아버지', '베르디', '명작\n'],
#  ['명곡', '리메이크\n'],
#  ['첫', '내한', '예상', '세트리스트\n'],
#  ['\n'],
#  ['크리스마스', '노래', '퐁당', '빠져\n'],
#  ['이런', '어쿠스틱', '분위기', '있', '팝송', '추천', '채우\n'],
#  ['듣', '카톡', '프로필뮤직', '바꾸', '봄감', '가득', '노래\n'],
#  ['나른', '시간', '채우', '달콤', '뉴에이', '지\n'],
#  ['한', '주말', '함께', '뮤직', '수시업\n'],
#  ['혹시', '오늘', '하', '우울\n'],
#  ['그냥', '틀', '좋', '힙합', '팝\n'],
#  ['여름', '바다\n'],
#  ['따뜻', '카페', '듣', '재즈', '캐롤', '연주곡\n'],
#  ...]

# %%
len(morphs)
# Out:
# 115071

# %%
morphs[1][-1]
# Out:
# '말\n'

# %%
for i in range(0,len(morphs)):
    morphs[i][-1] = morphs[i][-1].rstrip('\n')
morphs
# Out:
# [['여행', '같', '음악'],
#  ['요즘', '너', '말'],
#  ['편하', '잔잔', '듣', '있', '곡'],
#  ['크리스마스', '분위기', '흠뻑', '취하', '때'],
#  ['추억', '노래'],
#  [''],
#  ['짝사랑', '고백', '사랑', '이별', '슬픔', '감성', '자극', '곡'],
#  ['멍청', '나', '맘', '모르'],
#  [''],
#  ['록', '메', '탈', '이일우'],
#  ['걸그룹', '때', '쓰쏭'],
#  ['노래', '의지', '불태우', '짐', '프로', '필뮤직'],
#  ['지치', '너', '위로', '제목', '편지', '준비'],
#  ['트렌디', '그루브', '힙합', '알앤비'],
#  [''],
#  ['걍', '게임', '하', '때', '듣', '음악'],
#  ['나', '알', '노래'],
#  ['축가듀엣'],
#  ['이렇', '비', '내리', '날', '너', '나', '생각', '하'],
#  ['올림픽', '스밍', '목록'],
#  ['조용히', '맥주', '한잔', '하', '때', '새벽', '감성'],
#  ['ᴡ', 'ᴛɪ', 'ᴊ', 'ᴄ'],
#  ['추억', '명화', '만나', '시간', '영화', '모음'],
#  ['기분', '좋', '여름날'],
#  ['지치', '하루', '끝', '힐', '링', '필요', '당신', '추천', '인디곡'],
#  ['새벽', '찬바람', '침대위', '감', '쌀', '때', '국외'],
#  ['기분', '좋', '햇살', '같', '숨기', '명곡'],
#  ['사랑', '남녀', '듀엣'],
#  ['즐기', '듣', '소래'],
#  ['닥힙추'],
#  ['거', '슈윈', '스타', '워', '즈', '미국', '대표', '클래식'],
#  ['겨울', '기다리', '미리', '들'],
#  ['아침', '상쾌', '빅', '밴', '드', '스윙스윙'],
#  ['여행가', '길', '이런', '음', '악', '함께', '고고씽'],
#  ['믿', '듣', '하우스', '일렉트로니카'],
#  ['프로', '포', '즈', '음악'],
#  ['보', '일본', '곡'],
#  ['안다르', '레깅', '스', '입', '운동', '시작'],
#  ['발', '라', '드', '감성', '발', '라', '드림', '슬픔주의'],
#  ['크리스마스', '책임', '질', '캐롤', '모음'],
#  ['아무것', '위', '되', '때', '위로', '되', '음악'],
#  ['트렌디'],
#  ['우리나라', '라디오', '흘러나오', '명곡'],
#  ['영화', '만나'],
#  ['우울', '시크'],
#  ['극도', '우울', '때'],
#  ['폭팔', '밴드', '모음', '집'],
#  ['금쪽같', '휴일', '혼자', '시간', '방해'],
#  [''],
#  ['여자', '듣', '힙합'],
#  ['그', '루브', '넘치', '센스', '있', '음악'],
#  ['나', '듣'],
#  ['내', '듣', '중화', '노래'],
#  ['책', '함께', '편안', '듣', '연주곡'],
#  ['이', '달', '인디', '포크'],
#  ['가슴', '시리', '사랑', '노래'],
#  ['유럽', '여행', '어울리', '팝뮤직'],
#  ['사무실', '공기'],
#  ['이별', '후', '당신', '마음', '울리', '노래'],
#  ['불타', '금요일', '저녁', '더욱', '기분업', '시키', '노래'],
#  ['가을', '카페'],
#  ['취향', '저격', '앨범아트'],
#  ['최대한', '듣', '편하'],
#  ['여자', '좋아하', '남자', '노래', '방곡'],
#  ['졸음', '운전방지', '댄스', '댄', '플레이리스트'],
#  ['연애', '세포', '깨우', '설', '렘', '뿜뿜', '노래'],
#  ['천상', '지희', '시간순', '명곡', '좋', '백개이상'],
#  ['수능', '시험화이팅', '보컬곡'],
#  ['퇴근길', '클래식', '이야기'],
#  ['서바이벌', '프로그램', '헤드라이너', '가', '남기', '논쟁'],
#  [''],
#  ['도시', '밤', '어울리', '세련', '그루브'],
#  ['고속도로', '뚫', '얼른', '듣', '듣'],
#  ['이별', '거짓말', '제발가지마'],
#  ['포근', '이불속'],
#  ['비', '오', '날', '듣', '가슴', '두근두근'],
#  ['군산', '쿠바', '클럽', '노래'],
#  ['베스트'],
#  ['섹', '시', '비트'],
#  ['무게', '다르', '해외', '헤비메탈', '모음'],
#  ['해변', '드라이브'],
#  ['힐', '링', '필요', '신분', '한곡', '한곡', '천천히', '들'],
#  ['느낌', '있', '크리스마스', '쏭'],
#  ['아무', '때', '듣', '좋', '뉴에이', '지'],
#  [''],
#  ['정열', '라', '틴', '음', '악'],
#  ['기분', '좋', '음악', '모음'],
#  ['가을밤', '풀소리', '함께', '듣', '뉴에이', '지'],
#  ['상쾌', '아침', '열', '싱그럽', '뉴에', '지', '음악'],
#  ['공통', '감각'],
#  ['혼자남', '기', '진밤'],
#  ['언제', '효과', '만점인', '매력', '힙합'],
#  ['눕', '때', '아무', '생각', '없이'],
#  ['편견', '금물', '여름', '끝맺', '니엘', '저스디스', '만남'],
#  ['드라이브할때', '신', '나', '곡'],
#  ['듣', '다른', '곡', '듣', '되', '마성', '목소리', '모음'],
#  ['안구', '촉촉히', '적시', '노래'],
#  ['이유', '없이', '센치', '그런', '날', '당신', '들려주', '픈', '노래'],
#  ['걸', '그', '룹', '발라드', '명곡', '모음'],
#  ['듣', '노래'],
#  ['잔잔', '웅장', '락', '들'],
#  ['감각', '멜로디', '중독', '있', '비트'],
#  ['악동', '서', '울', '런', '쥐', '추천곡'],
#  [''],
#  ['흔들리', '벚꽃', '속', '들', '봄', '노래'],
#  ['때껄룩', '때껄', '룩', '사랑', '지상', '최고', '플레이리스트'],
#  ['자주', '듣', '노래', '목록'],
#  ['늦', '밤', '듣', '곡'],
#  [''],
#  ['퇴근길', '하루', '마무리', '재즈'],
#  ['나', '혼자', '카페', '분위기', '내', '때'],
#  ['휴일', '기분', '전환', '어쿠스틱'],
#  ['센티멘탈', '플레이리스트', '센치', '분위기', '다', '모이'],
#  ['어쿠스틱', '부흥', '선도', '언플러그드', '라이브'],
#  ['신해철', '이제', '아픔없', '곳'],
#  ['클럽못갈때', '이거', '대리', '만족'],
#  ['무덥', '여름', '댓츠노노', '나', '상', '큼', '노래', '시원'],
#  ['듣', '좋', '추천곡'],
#  ['치명', '치정', '사랑'],
#  ['한', '음악', '너무', '따분', '때'],
#  ['폭', '풍', '드라이브', '운동', '때', '위하', '극강', '락사운드', '과속주의'],
#  ['여돌', '타이틀', '곡', '모음'],
#  ['지금', '주목', '인디', '뮤직'],
#  ['잠', '안', '오', '때', '듣', '자장'],
#  ['영상', '배경음', '매장', '추천'],
#  ['일', '렉', '트', '로닉', '한', '들', '너무', '좋'],
#  ['매일', '듣', '노'],
#  ['듣', '기분', '좋', '가요'],
#  ['나', '알', '피아노', '곡'],
#  ['감성', '충전', '선율', '아름답', '피아노', '연주곡'],
#  ['흥', '겨', '우'],
#  ['운동', '아드레', '날리', '폭발'],
#  ['주말', '밤', '푹', '잠들', '때', '듣', '수면', '유도', '음악'],
#  ['덕후', '모', '여', '랏'],
#  [''],
#  ['보', '싸', '다방', '커피', '향기'],
#  ['앗', '듣', '더', '신기', '동화'],
#  ['새벽', '위하', '노래', '잔잔', '몽', '환'],
#  ['아', '나', '연애'],
#  ['나', '곡'],
#  ['쇼', '미', '더머니', '노래', '모음'],
#  ['아침', '활력', '위하'],
#  ['가을밤', '니', '생각나', '그런', '밤'],
#  ['가을밤', '드라이브할때', '듣', '편하', '곡'],
#  ['기타', '들', '노래', '영국', '뮤지션'],
#  ['멜로디', '포레', '스', '트', '캠프', '최종', '라인', '업'],
#  ['아무', '일단', '신', '나', '노래', '틀'],
#  ['혼자', '있', '때'],
#  ['비', '오', '날', '감성', '자극', '듣', '좋', '어쿠스틱', '피아노', '발라드'],
#  ['이브날', '듣', '그립', '로맨', '틱', '멜로디'],
#  ['주말', '도시', '야경', '바라보', '듣', '좋', '노래'],
#  ['오늘', '왠지', '꿀꿀', '나', '웃', '클래식', '음악'],
#  ['밤', '생각나', '음악'],
#  ['여름', '노래', '멜론', '추천'],
#  ['그렇', '지나가'],
#  ['빌보드', '일자'],
#  ['가을', '문턱', '잊', '나', '감성', '깨우', '클래식'],
#  ['주말', '힐링', '연주곡'],
#  ['가을', '저녁'],
#  ['뚫', '뻥', '스트레스', '사라지', '위대', '노래'],
#  ['이별', '후', '듣', '더', '슬프', '감성', '발라드', '인디', '노래'],
#  ['취존', '수정'],
#  ['마음껏', '울', '때'],
#  ['귀', '말랑', '인디음악'],
#  ['고음병', '걸리', '당', '신', '위하', '명품발라드', '선', '여자', '가수편'],
#  ['무현', '반하', '힙'],
#  ['사랑', '연인', '잡', '때'],
#  ['섹', '시', '발', '언니', '노래'],
#  ['빗물', '흐르', '플레이리스트'],
#  ['웃', '안녕', '감성', '노래'],
#  ['봄', '담', '설', '렘', '가득', '달달', '음악'],
#  ['음악', '함께', '산책', '그리고', '행복', '상상'],
#  ['크리스', '마스'],
#  ['스', '쿨', '오브', '힙합', '초급'],
#  ['거짓말', '같', '이별', '이야기'],
#  ['놀랍', '주', '은혜'],
#  ['일자', '빌보드'],
#  ['어디', '가', '힙알', '못', '소리', '듣', '해외'],
#  ['자신감', '충전', '파워워킹', '비트', '좋', '음악'],
#  ['마커스', '워', '십', '은혜', '받'],
#  [''],
#  ['기분', '전환', '필요', '때', '듣', '음악'],
#  ['주말', '기다리', '마음', '정화', '노래', '가요', '팝송'],
#  ['오직', '기타', '목소리', '이루어지', '감성', '포크'],
#  ['달', '새벽', '그리고', '잠', '오', '나'],
#  ['민아', '추천곡'],
#  ['운동', '듣', '힘나', '빠르', '댄스곡'],
#  ['기분', '좋', '하루', '시작', '산뜻', '재즈', '함께'],
#  ['심포닉메탈', '넘져'],
#  ['정신', '차리', '이미', '댄스', '무아지경', '댄스', '음악'],
#  ['사이다', '청량', '톡톡', '터지', '노래'],
#  ['나', '성향', '향기'],
#  [''],
#  ['욕', '나올정도', '좋', '해외', '알앤비'],
#  ['클럽', '홀', '릭', '내한', '공연'],
#  [''],
#  ['모음', '집'],
#  ['발레', '음악', '클래식', '베스트'],
#  ['겨울', '어울리', '감성비트', '특별', '연말', '보내'],
#  ['도입', '부', '느낌', '오'],
#  ['에너지', '팍팍', '노동요'],
#  ['너무', '달달', '귀', '녹아내리', '곡'],
#  ['디제잉휘'],
#  ['기분', '우울', '때', '힙', '신', '나', '팝송'],
#  ['달리'],
#  ['오늘', '치', '힘들', '나', '편안', '잠들', '음악'],
#  ['도시', '벗어나', '바다', '가', '이', '노래', '틀'],
#  ['여름', '명곡', '듣', '당장', '시원', '여름', '노래'],
#  ['밤', '듣', '감성', '팝'],
#  ['운동', '필요', '당신', '위하', '발레', '음악', '클래식'],
#  ['마지막', '주', '퇴근', '플레이리스트'],
#  ['소', '울', '태동기', '대중', '다가오', '소울', '대표', '뮤지션'],
#  ['믿', '듣', '작사', '작사', '김영후'],
#  ['내한', '공연', '예상', '셋', '리', '스', '트'],
#  ['선', '버터', '플라이'],
#  ['빌보드', '인기', '팝송', '듣', '즐겁'],
#  [''],
#  ['이후', '국내', '힙합신', '새롭', '급부상', '뉴페이스들'],
#  ['삶', '구석지', '곳', '이야기', '가사'],
#  [''],
#  ['나이테', '같', '노래'],
#  ['독서', '어울리', '감미', '연주', '음악'],
#  ['멜로', '하'],
#  ['멜로디', '좋', '미디움템포', '팝', '나른', '커피한', '잔', '하', '때', '필요', '플레이리스트'],
#  ['몽환러버', '감성'],
#  ['비', '오', '날', '새벽', '듣', '좋', '노래'],
#  ['주말', '함께', '하', '힐링', '뮤직'],
#  ['봄', '듣', '살랑살랑', '시티팝', '느낌'],
#  ['비', '오', '요즘', '기분', '우울'],
#  ['목요일'],
#  ['후기', '바로크', '세기후', '세기'],
#  ['합법', '떨'],
#  ['수록', '곡', '반란'],
#  ['가을가을', '매장', '음악'],
#  ['주간', '인디', '발견'],
#  ['라디오'],
#  ['크', '러', '시', '원조', '되', '그룹'],
#  ['댄', '스', '팝송', '모음'],
#  ['봄', '기다리', '듣', '따뜻', '사랑', '노래'],
#  ['세련', '스타일', '요즘', '들', '보'],
#  ['댄스', '팝', '틀', '신', '나', '춤추', '스트레스', '풀자'],
#  ['미리', '메리', '크리스마스'],
#  ['진짜', '개띵곡', '모음'],
#  ['이센스', '읊조리'],
#  ['빌', '보', '드', '차트', '곡', '모음집'],
#  ['장르', '퓨쳐베', '이스', '몽롱', '감상', '일', '렉'],
#  ['힘들', '때', '마', '음편히', '들', '있', '발라드'],
#  ['두', '느낌', '듣', '빠르', '버전'],
#  ['비', '오', '날', '듣', '가사', '슬프', '노래'],
#  ['듣', '나', '모르', '리듬타', '만들', '노래'],
#  ['여름', '방학'],
#  ['잠', '오', '밤', '고요', '방', '안', '듣', '노래'],
#  ['우리', '카페', '들려주', '크리스마스', '캐럴'],
#  ['나', '크레바스'],
#  ['잠', '오', '오늘', '밤', '함께', '노래', '모음'],
#  ['테크노', '음악'],
#  ['빌보드', '선정', '가장', '크', '히트곡', '최고', '곡'],
#  ['가을', '듣', '좋', '음악', '무엇'],
#  ['쿨', '보내', '아직', '이별'],
#  ['부담', '없이', '듣', '좋', '인디음악'],
#  ['비트', '짱', '좋', '곡', '모으', '흔하', '팝송', '귀르가즘', '꼬', '우'],
#  ['시원', '바다', '그립', '오늘'],
#  ['재중', '런칭파티', '패션쇼'],
#  ['드라이브', '하', '때', '이', '음악', '틀'],
#  ['신', '나', '크리스마스', '어울리', '캐롤', '노래', '준비', '너', '위하'],
#  ['출근길', '학교가', '길', '듣', '음악'],
#  ['후덥지근', '여름', '밤', '불쾌지수', '낮추', '힐링클', '래식'],
#  ['둠칫둠칫', '걷', '때', '듣', '좋', '음악'],
#  ['외국펍', '즐기', '느낌', '음악'],
#  ['엄선', '명곡', '모으'],
#  [''],
#  ['뷰티샵', '듣', '한', '느낌', '패셔너블', '팝'],
#  [''],
#  ['음악', '맺', '사랑', '부부', '되', '뮤지션', '대표곡'],
#  ['여름', '추천곡', '모음'],
#  ['장르', '불문', '내맘', '플레이리스트'],
#  ['언제나', '듣', '좋', '젊', '힙합'],
#  ['주간', '탄식', '빵'],
#  ['부모', '생각', '쓰', '가사', '모음'],
#  ['나', '우효'],
#  ['이브', '콘서트'],
#  ['푸', '르', '밤', '플레이리스트'],
#  ['미', '세', '먼', '지', '쌓이', '답답', '날리'],
#  ['내', '듣', '저장', '노래'],
#  ['라디오'],
#  ['기분', '노래'],
#  ['밥', '먹', '다니', '밥', '먹', '이', '노래', '듣'],
#  ['밤잠', '설치', '당신', '위하', '밤감', '노래'],
#  ['겨울', '정취', '느끼', '있', '클래식'],
#  ['공부', '하', '때', '집중력', '올리', '주', '클래식'],
#  ['운동', '욕구', '상승', '클럽음악', '트레이닝'],
#  ['달콤', '음악데이트'],
#  ['포크', '싱', '어', '송라이터', '리바이벌'],
#  ['요즘', '즐기', '듣', '인디', '노래'],
#  ['춥', '겨울', '조용', '새벽', '듣', '노래'],
#  ['어둠', '내려앉', '저녁', '듣', '발라드'],
#  ['팝씬', '여행', '쿨', '키', '즈', '위하', '안내'],
#  ['달콤', '보사노바'],
#  ['방탄', '타이틀', '곡', '모음'],
#  ['우리', '아이', '재우', '자장', '모', '음'],
#  ['길거리', '절대', '듣', '안', '음악'],
#  ['뉴에이', '지'],
#  ['자유', '행보', '이면', '숨기', '예술'],
#  ['재즈', '최신곡', '모음집'],
#  ['봄', '오', '소리'],
#  ['아이돌', '파헤치'],
#  ['가을', '드라이브', '듣', '좋', '노래'],
#  ['혼자', '시간', '보내', '듣'],
#  ['카페', '흘러나오', '포근', '음악'],
#  ['잔디', '초원', '풀잎내음', '양떼', '구름', '목장'],
#  ['혼자', '듣', '아깝', '노래', '감성'],
#  ['몽글몽글', '샤워', '듣', '적절', '노래'],
#  ['감성', '재즈'],
#  ['기억속', '잔잔', '발라드'],
#  ['운동', '때', '에너지뿜뿜'],
#  ['나른', '주말', '오후', '채우', '노래'],
#  ['편안', '아침', '열', '팝송'],
#  ['우울', '때', '신', '나', '댄스곡'],
#  ['라디오', '목', '그', '날', '음악'],
#  ['따뜻', '어쿠스틱'],
#  ['봄', '듣', '좋', '팝송'],
#  ['많', '사람', '알', '하', '노래'],
#  ['유튜브', '조회수', '알아보', '핫한', '요즘'],
#  ['빌보드'],
#  ['위로', '힘들', '지치', '이'],
#  ['잠시', '내리', '비', '촉촉', '여름', '오후', '어울리', '음악'],
#  ['버스', '안', '듣', '노래'],
#  ['흘러가', '편하', '듣', '때'],
#  ['달', '달', '여름', '밤'],
#  ['그냥', '엄청', '달', '달'],
#  ['공부', '수면', '위하', '백색', '소음', '편안'],
#  ['아이돌', '컴백', '전쟁', '퀸덤', '원곡모', '음'],
#  ['사무실', '플레이리스트'],
#  ['도입부', '매력', '인디곡'],
#  ['간지녀', '간지남', '들', '듣', '신박', '팝', '가요', '모음'],
#  ['둠칫둠칫', '리듬', '저절로', '타지', '팝', '모음'],
#  ['내', '좋아하', '노래'],
#  ['기쁨'],
#  ['퇴근', '길', '귓가', '울리', '퍼지', '뮤직'],
#  ['핵인싸', '국내', '힙합', '플레이리스트', '매일업', '데이', '트'],
#  ['스티비', '원더', '히트곡'],
#  ['꿀꿀', '때', '밝', '자신', '있'],
#  ['겨울밤하늘', '바라보', '듣', '몽환송'],
#  ['카페', '듣', '좋', '노래'],
#  ['힘들', '지치', '때', '힘', '되', '노래'],
#  ['발렌타인', '이', '누구', '다가오', '기다리'],
#  ['집중', '허전', '때'],
#  ['흐리', '바람', '불', '날', '좋아하', '너'],
#  ['클럽', '액기스', '드루', '업뎃완료'],
#  ['외사랑', '짝사랑', '너', '보내'],
#  ['머리', '맑', '부드럽', '뉴에이', '지', '피아노연주곡', '모음'],
#  ['재즈', '최신곡', '모음집'],
#  [''],
#  ['팝'],
#  ['러브숑'],
#  ['달', '달', '극치', '플레이리스트'],
#  ['몽환', '서정', '노', '이', '즈', '미학', '슈게이', '징'],
#  ['이별', '직후', '검색', '추가'],
#  ['우주', '소녀', '우정', '만남', '아름답', '노래', '통하', '이루어집'],
#  ['테스트', '플레이'],
#  ['한국', '전통', '음악', '편견', '깨'],
#  ['도입부', '듣', '느낌', '오', '노래'],
#  ['듣', '지'],
#  ['가을', '사랑', '그', '쓸쓸', '대하'],
#  ['주간', '일', '렉', '트', '로', '니카', '라디오', '발매곡'],
#  ['피아노', '소리', '너무', '예쁘', '노래'],
#  ['신곡', '인디'],
#  ['감', '성', '인', '겨울', '발라드'],
#  ['잔잔', '이', '밤', '분위기', '좋', '발라드'],
#  [''],
#  [''],
#  ['우울', '때', '듣', '더', '우울', '노래'],
#  ['선'],
#  [''],
#  ['흐리', '날', '선곡', '좋', '주말카페', '들리', '감성', '깊', '멜로디', '보이스라떼'],
#  ['매력', '보이스', '남성보컬', '음악'],
#  ['외국'],
#  ['요즘', '빠지', '노래'],
#  ['올드', '팝', '즐기', '연말', '파티'],
#  ['너', '나', '시간'],
#  ['그', '시절', '그', '노래'],
#  ['빌보', '드', '기념', '빌보드', '빛내', '역대', '싱글'],
#  ['헤어지', '겨울'],
#  ['생각', '정리', '필요', '때', '필요', '피아노', '연주곡'],
#  ['오늘', '추천곡'],
#  ['마음', '따뜻', '편안', '힐', '링', '재즈'],
#  ['콜라', '보', '레이', '션'],
#  ['조용', '카페', '어울리', '분위기', '있', '노래', '모음집'],
#  ['맞이'],
#  ['인디', '듣', '때'],
#  ['듣', '기분', '좋', '달콤', '멜로디'],
#  ['듣', '신', '나'],
#  ['카페', '듣', '좋', '음악', '감성가', '득', '취향', '저격', '피아노연주곡'],
#  ['듣', '곡', '가장', '슬프', '발라드', '모음'],
#  ['매력', '몽환'],
#  ['운동', '때', '듣', '힘', '들', '잊', '되'],
#  ['크리스마스', '분위기', '물씬', '나', '곡들', '총집'],
#  ['폰부스', '예습', '곡'],
#  ['급외로울때', '듣', '기분', '좋', '노래'],
#  ['뉴에이', '지', '피아노', '함께', '감성', '시간'],
#  ['눈물없', '이', '듣', '없', '슬픔', '발라드'],
#  ['잠', '안', '오', '새벽', '나', '대신', '울', '이별', '노래'],
#  ['아이', '신', '나', '신체놀이', '시간'],
#  ['배경', '음악', '쓰이', '웅장'],
#  ['나른', '오후'],
#  [''],
#  ['주인공', '부르'],
#  ['밤', '듣', '발라드'],
#  ['카페', '책', '읽', '때', '나른', '피아노', '연주곡', '함께'],
#  ['한', '듣', '하', '노', '래'],
#  ['최고', '기타리스트', '그', '밴드', '선보이', '하드록', '헤', '비메탈', '명곡선'],
#  ['선곡', '좋', '들리', '달달', '봄', '캐롤송'],
#  ['이름', '드러나', '로큰롤', '명예', '전당', '후보'],
#  ['트', '렌', '디', '매장', '듣', '좋', '곡'],
#  ['간질간', '질', '간절기', '단풍', '단풍', '가을'],
#  ['한', '소절', '듣', '빠지', '노래'],
#  ['어둡', '새벽', '새까맣', '하늘', '그림', '그리'],
#  [''],
#  ['트렌디'],
#  [''],
#  ['아이돌', '명곡', '모으'],
#  ['빵빵', '떠', '아이돌', '그룹', '명곡'],
#  ['누구', '그립', '때'],
#  [''],
#  ['명상', '독서', '때', '듣', '클래식'],
#  ['무더위', '고생', '당신', '청량', '비트감', '사운드'],
#  ['가사', '멜로디', '좋', '국내', '발라드'],
#  ['추억', '담기', '노래'],
#  ['명품', '남녀', '듀엣곡', '엄선', '곡', '모음'],
#  ['나', '귀'],
#  ['집중력', '향상', '클래식', '사색', '위하', '클래식'],
#  ['개강', '기념', '학생증', '제시', '프리패', '스'],
#  ['어리', '시절', '잠결', '흘리', '토요', '명화', '생각나', '영화', '보컬'],
#  ['사랑', '잔잔', '경계'],
#  ['감미', '피아노', '선율', '재즈곡'],
#  ['흥폭팔', '둠', '칫두둠', '칫', '필요', '감각', '팝'],
#  ['설', '레', '노래'],
#  ['처음', '오', '손', '단골', '매장', '음악'],
#  ['비', '오', '날', '감성', '있'],
#  ['언더', '커버', '뮤직'],
#  ['카페', '듣', '연주곡'],
#  ['하루', '마무리', '편안', '음악'],
#  ['헤이즈', '모음'],
#  ['누에보깐시온', '향기'],
#  ['이소라', '기념', '많', '신청곡', '여기', '같이', '들'],
#  ['추억', '발라드'],
#  ['발라드', '솔로'],
#  ['내맘', '사심'],
#  ['가을밤', '혼자', '생각', '잠기', '때'],
#  ['감성', '폭발'],
#  ['외로움', '달래', '가사', '없', '연주', '음악', '특선'],
#  ['남녀', '듀엣곡', '아름답', '곡'],
#  ['북카페', '울리', '퍼지', '잔잔', '음', '악'],
#  ['상반기', '나의소울'],
#  ['잔잔', '노래', '듣', '때'],
#  ['여름', '오', '들썩들썩'],
#  ['요즘', '참', '몽환', '음악', '끌리'],
#  ['신', '나', '금요일', '우리', '오늘', '해'],
#  ['퇴근길', '다소', '멜랑', '리', '잠깐', '밟'],
#  ['청각', '미각', '신', '맛'],
#  ['명품', '명품', '골든', '발라드'],
#  ['가을밤', '듣', '좋', '노래'],
#  ['감각', '세련', '매장'],
#  ['겨울', '듣', '인디', '팝'],
#  ['방해', '받', '나', '위하', '휴가', '음악'],
#  [''],
#  ['아티스트', '추천', '테스트', '따옴표'],
#  ['헬스장', '운동', '때', '듣', '좋', '누구', '신', '나', '노래'],
#  ['듣', '듣', '좋', '분위', '기갑', '아이돌', '명곡'],
#  ['잔잔', '신남', '그', '사이', '어디'],
#  ['오리지날', '버전', '어쿠스틱', '버전'],
#  ['머리', '맑', '기분', '좋', '뉴에이', '지'],
#  [''],
#  ['여름', '밤', '잔디밭'],
#  ['팝송', '몇몇', '좋', '곡', '고르', '보'],
#  ['여름', '어울리', '시원상쾌'],
#  [''],
#  ['오늘', '혼자', '시간', '필요'],
#  ['가을', '여행', '함께', '하', '낭만', '재즈'],
#  ['광고', '음악', '어울리', '감각', '음악'],
#  ['가을', '밤', '어울리', '감성보컬', '알앤비', '모음'],
#  ['고장난', '라디오', '오후'],
#  ['가을동화', '나', '삶', '눈물', '채우', '그', '립', '음악'],
#  ['연애초기', '달달', '설레', '설레', '노래'],
#  ['나', '가수', '차', '미리', '듣'],
#  ['그대'],
#  ['노래', '모음'],
#  ['카푸치노', '음악', '한', '방울'],
#  ['보통날'],
#  ['듣', '노래'],
#  ['따뜻', '커피', '한잔', '음악', '한조각'],
#  ['눈', '감', '듣', '힐링', '음악'],
#  ['수면제', '대신', '이', '노래', '듣', '잠', '들'],
#  ['뉴욕', '가을도시', '낭만'],
#  ['기분', '좋', '하루', '나', '힘나', '노래'],
#  ['테스타먼트', '거치', '가', '드', '러머', '환상', '명연주'],
#  ['한', '들어보', '추천곡', '모음집'],
#  ['옥타곤', '내한', '마티스', '사드코'],
#  ['밴드음악', '듣'],
#  ['너', '선물', '음악', '꽃'],
#  ['코첼라', '페스티벌', '강력', '일', '렉트', '로', '닉', '음악', '페스티벌', '되', '있', '이유'],
#  ['톡톡', '튀', '몽', '환곡'],
#  ['남자', '아이돌', '노래', '모음'],
#  ['걸그룹', '발라드', '명곡'],
#  ['가을', '끝', '잔잔', '음악', '필요', '때'],
#  ['드라마', '끝나', '남'],
#  ['조금', '남다르', '음악', '박자'],
#  ['서울재즈', '페스티벌'],
#  ['월요병', '이기'],
#  ['어서', '오', '힐링곡', '맛집입니', '당'],
#  ['춥', '겨울', '따뜻', '손난로', '같', '고막', '남여친', '감성', '노래'],
#  ['가만히', '눕', '듣', '오후', '피크닉'],
#  ['터보', '종국', '근육맨'],
#  ['조용필'],
#  ['마음', '정화'],
#  ['무한도전', '위대', '유산'],
#  ['드라브', '조용', '강변', '카페', '커피한잔', '하', '잔잔', '음악', '함께'],
#  ['노래', '만나', '재즈', '스탠더드'],
#  [''],
#  ['산책', '때', '듣', '적당히', '흥나'],
#  ['또', '한', '여름', '오'],
#  ['나', '모르', '들썩거리', '노래'],
#  ['쇼미', '더', '머니', '프로듀서', '스페셜', '코드', '쿤스트', '팔로알토'],
#  ['니드', '포', '스피드', '엣지'],
#  ['아메리카', '노', '한', '잔', '가볍', '출근길'],
#  ['일요일', '드라이브', '하', '듣', '딱', '좋', '노래'],
#  ['집', '있', '집', '가', '때', '찾', '듣'],
#  ['오늘', '추천곡'],
#  ['따듯', '욕조', '신욕', '듣', '힐링', '음악'],
#  ['첫', '소절', '듣', '느낌', '오', '곡'],
#  ['센치', '때', '듣', '딥한', '감성', '팝'],
#  ['여름', '여행', '분위기'],
#  ['익숙'],
#  ['일', '렉', '트로', '니', '카', '파생', '랩', '음악'],
#  ['그', '날', '좋', '곡', '발행'],
#  ['클럽', '인트', '플레이리스트'],
#  ['흑', '인스멜', '코', '리안', '뮤직', '탄'],
#  ['요즘', '가장', '핫', '하', '일렉', '팝', '아주', '그냥'],
#  ['뉴에', '지', '신', '곡', '모음집'],
#  ['갈매', '기공', '화국', '알'],
#  ['피아노', '첫', '걸음', '바이엘', '연습곡'],
#  ['가수바', '기', '베스트'],
#  ['머리맡', '틀', '자기', '좋'],
#  ['한', '들어', '필수', '팝송', '모음'],
#  ['올해', '록', '앨범', '국내', '국외'],
#  ['매', '일', '들', '질리', '스테디셀러', '같', '노래'],
#  ['썸', '데이트', '때', '듣', '재즈'],
#  ['사랑', '시작', '설레임'],
#  ['여름', '시원', '댄스', '음악'],
#  ['달콤', '노래'],
#  ['잠들', '전', '편안', '듣', '클래식음악'],
#  ['불면증', '특효약', '여름밤', '듣', '좋', '노래'],
#  ['조용히', '혼자', '듣', '때', '네엣'],
#  [''],
#  ['아련', '봄', '오', '봄향기', '느끼', '노래'],
#  ['서울재즈페', '스티벌'],
#  ['발라드', '모음', '공간', '입'],
#  ['지나가', '지나가', '위로', '되', '노래'],
#  ['이별', '시작'],
#  ['차안', '듣', '좋', '노래'],
#  ['걸', '그룹', '여름', '히트곡'],
#  ['퇴근길', '듣', '만', '플레이리스트'],
#  ['일자', '독일', '싱글', '차트'],
#  ['다시', '봄', '뭐', '설레', '요즘', '감성', '더', '촉촉', '만들', '노래'],
#  ['새벽', '혼자', '너', '생각'],
#  ['달콤', '힙합', '다정', '발라드'],
#  ['프', '레', '시업'],
#  ['피아노', '기타', '어우르', '어쿠스틱', '음악'],
#  ['어느', '멋지', '가을날'],
#  [''],
#  ['주관', '한국', '아이돌', '명곡', '모음', '추천', '받'],
#  ['환상', '케미스트리'],
#  [''],
#  ['친구', '함께', '동화', '들'],
#  ['카페', '듣', '좋', '음악'],
#  ['출근길', '활기차', '만들', '노래'],
#  ['봄', '듣', '크리스마스', '송'],
#  [''],
#  ['밤하늘', '별', '수놓', '국내', '모'],
#  ['래', '퍼', '감성', '느끼', '띵곡들'],
#  ['조용조용', '방탄', '소년단'],
#  [''],
#  ['달달', '노래', '임시', '저장'],
#  ['새벽', '듣', '좋', '감성', '노래', '모음'],
#  ['여자', '아이돌', '히트곡', '모음', '걸그룹', '여돌', '솔', '로'],
#  ['국내', '감성', '모음'],
#  ['트와이', '스', '국민', '걸그룹', '만들', '블랙아이드', '필', '승'],
#  ['이', '주의', '마지막주'],
#  ['아무', '로', '나', '미'],
#  ['커피', '찰떡궁합', '알', '앤비', '힙합'],
#  ['공부', '때', '가볍', '듣', '음악'],
#  ['가을', '노래'],
#  ['똑', '똑', '겨울', '노래', '도착입니닷'],
#  ['이', '노래', '진', '짜', '섹', '시'],
#  ['어둡', '밝', '푸르', '새벽', '같', '곡'],
#  ['신', '나', '리', '드미컬', '노래', '원하', '당장', '클릭'],
#  ['카페', '힐링', '듣', '노래', '카페', '힐링'],
#  ['노래틀고', '울'],
#  ['멋', '취향', '저격', '과하', '신나', '사운드'],
#  ['한', '듣', '하루동안', '신', '나', '노래'],
#  ['숙면', '연애', '세포', '깨우', '노래'],
#  ['자기', '전', '듣', '좋', '따뜻', '목소리'],
#  ['따뜻', '봄날', '외출', '위하', '얼터너티브', '팝'],
#  ['올', '크리스마스', '캐롤'],
#  ['달콤', '살', '벌', '썸', '남', '썸녀', '노래'],
#  ['팝스타', '한국어', '패치', '완료', '수시', '업데이트'],
#  ['비오', '들', '매장', '마감곡'],
#  [''],
#  ['듣어'],
#  ['운동', '할때'],
#  ['피아니스트', '명', '모음'],
#  ['오', '같', '느낌', '주'],
#  ['나', '고막', '책임지', '계속', '듣', '되', '달', '달', '구리', '노래'],
#  ['아무', '일', '없', '듣', '감성', '터지', '음악'],
#  ['이', '노래', '듣', '가을', '냄새', '느끼'],
#  ['일자', '프랑스', '싱글', '차트'],
#  ['어', '린시절', '추억', '만화', '영화주제곡', '베스트'],
#  ['잠들', '전', '연인', '들려주', '달콤', '자장'],
#  ['살', '한', '꼭', '듣', '되', '베토벤', '작품'],
#  ['지나', '기억', '누구', '그립', '때'],
#  ['운동', '때', '힙한', '느낌', '가득', '챙기', '감각', '신', '나', '팝'],
#  ['아름답', '알앤', '비', '힙합'],
#  [''],
#  ['모든', '다', '내려놓', '때', '듣', '눈물', '나', '노래'],
#  ['주말', '휴식', '위하', '뉴에이', '지', '피아노', '음악'],
#  ['공개', '리스닝', '세션', '후기'],
#  ['한국', '힙합', '단체곡'],
#  ['새벽', '감', '촉촉'],
#  ['좋아하', '인디'],
#  ['팬텀싱어', '원곡'],
#  ['방탄', '소년단', '함께'],
#  ['리듬', '마라톤'],
#  ['빌보드', '일자'],
#  ['일렉빠', '모음', '집'],
#  ['추천', '입'],
#  ['점수', '묻', '떠블', '로', '가', '수능대박', '응원', '위로', '메시지'],
#  ['노래', '부르', '때', '모음', '항상업뎃중'],
#  [''],
#  ['무인', '가', '때', '가져가', '진짜', '발라드', '명곡'],
#  ['겨울', '공기', '머금', '몽환', '인디', '뮤직', '선'],
#  ['노창', '울', '가', '진짜', '미치', '곡', '모으'],
#  ['잠들', '밤', '잔잔', '듣', '있', '음악'],
#  ['가사', '공감', '노래'],
#  ['우울', '나락'],
#  ['중년', '나이트댄스곡'],
#  ['너', '목소리', '들리', '번외편'],
#  ['요즘', '듣', '어쿠스틱', '발라드'],
#  ['듣', '재미', '있', '피아노', '협주곡'],
#  ['자연', '소리', '심리', '안정', '위하'],
#  ['음악디자이', '너', '취향', '저격', '좋', '노래'],
#  [''],
#  ['뉴', '에', '이', '지', '함께', '좋', '아침', '열'],
#  ['청량', '시원', '노래', '드라이브곡', '여름'],
#  [''],
#  ['추천', '한', '여름', '밤', '발라드', '①'],
#  ['겨울', '끝', '봄', '기다리', '듣', '잔잔', '산뜻', '감성', '팝'],
#  ['기타소리', '좋', '노래'],
#  ['여름', '밤', '선선', '감성', '목소리', '전달', '노래'],
#  ['한국노', '래', '좋', '노래'],
#  ['요즘', '잘', '모르', '노래'],
#  ['노이즈', '공간감', '만들', '몽롱', '슈', '게', '이', '징'],
#  ['우리', '집', '흐르', '포근', '피아노', '음악'],
#  ['애정', '상징', '플레이리스트'],
#  ['나', '안', '감정', '우울'],
#  ['재즈'],
#  ['열'],
#  ['상큼', '락', '하루'],
#  ['쉽', '편하', '듣', '있'],
#  [''],
#  ['가끔', '발라드'],
#  ['신', '나', '유로팝'],
#  ['바람', '불', '야외', '듣'],
#  ['신화', '추억'],
#  ['겨울', '지나오', '듣', '따스', '어쿠스틱'],
#  ['추천', '곡곡'],
#  ['위클리초이스'],
#  ['감성', '그', '이름의노래'],
#  ['돌아가'],
#  [''],
#  ['흥', '돋우'],
#  ['겨울', '감성', '터지', '이별', '발라드', '노래방', '선곡'],
#  ['뉴이스', '트', '최애곡'],
#  ['노래'],
#  ['나', '시각', '청각', '훔치'],
#  ['팬'],
#  ['내', '뽑', '모음'],
#  ['춥', '날', '듣', '더', '좋', '노래', '같이', '들'],
#  ['오렌지', '빛', '하늘', '드리울', '때', '황홀', '드라이브', '위하', '시티', '팝'],
#  ['알앤비', '땡기', '지금', '금금금'],
#  ['듣', '좋', '세기말', '한국', '음악'],
#  ['아직', '성장'],
#  ['감성', '필충', '힙합'],
#  [''],
#  ['두둠칫', '흥', '절', '로', '돋', '음악', '모으'],
#  ['이스케이', '프', '코리아', '라인업', '발표'],
#  ['퇴근', '길', '함께', '따뜻', '발라드'],
#  ['클래식', '신', '곡', '모음집'],
#  ['듣', '순간', '가볍', '그루브', '타', '되', '노래'],
#  ['당신', '기분', '하', '껏', '올리', '주'],
#  ['나는노래'],
#  ['추억', '돋', '영혼', '있', '노래'],
#  ['감성', '젖', '있', '과거', '최고', '국내', '국외', '락발라드', '모음'],
#  ['클럽', '에덴', '맞', '이'],
#  ['캐주얼', '레스토랑'],
#  ['태', '연', '정규', '앨범'],
#  ['너', '지금', '뭐', '해', '자'],
#  ['힘', '좀', '내', '신', '나', '국내', '락'],
#  ['감수', '자극', '봄비', '오', '때', '생각', '많', '때', '듣', '좋', '피아노', '연주곡'],
#  ['혼자', '듣', '아', '깝', '음악'],
#  ['부활'],
#  ['개인', '플레이리스트'],
#  ['매장', '듣', '노래'],
#  ['평생', '듣', '질', '리'],
#  ['나', '맘대로', '상반기'],
#  ['무더위', '날리', '시원', '여름', '가요', '모음'],
#  ['띵곡', '모음집'],
#  ['알', '사람', '다', '알', '느낌', '있', '팝'],
#  ['멍때리'],
#  ['비', '오', '날', '잔잔', '느끼'],
#  ['일본', '노래', '모음'],
#  ['감성', '발라드'],
#  ['라디오'],
#  ['내적', '댄스', '유발', '곡'],
#  ['소울', '어쿠스틱', '합치'],
#  [''],
#  ['뮤직테라피', '스테디'],
#  ['차안', '분위기', '있', '듣', '노래'],
#  ['중복', '비', '오', '무조건', '신', '나', '음악', '함께'],
#  ['짬', '나오', '세대', '힙합', '래퍼'],
#  ['룸', '좋아하', '더', '많', '감성', '힙합'],
#  ['불후', '명곡', '전설', '노래', '특집', '김수철', '원곡'],
#  ['지브리', '애니메이션', '명곡', '만나', '피아노', '지브리', '콘서트'],
#  ['듣', '전투력', '상승', '곡', '외', '힙', '위주'],
#  ['한', '듣', '노래'],
#  ['집중', '작업', '도움이', '되', '음악'],
#  ['베이스', '사운드', '오', '지', '곡'],
#  [''],
#  ['인가구', '살'],
#  ['분위기', '있', '비트', '음악', '함께', '하루', '만들'],
#  ['감', '성자', '극', '음악', '모음'],
#  ['울', '웃', '잔', '잔한노래'],
#  [''],
#  ['취향타'],
#  ['내', '좋아하', '노래', '너', '좋아하', '하', '노래'],
#  ['카페', '새벽', '듣', '무', '있', '노래'],
#  ['새벽', '우울', '때', '듣', '우울', '끝', '노래'],
#  ['고백', '좋', '날'],
#  ['무더위', '듣', '시원', '느낌'],
#  ['귓가', '자꾸', '맴돌', '달달', '러브', '송'],
#  ['달콤', '달달', '로맨틱', '노래'],
#  ['비', '오', '날', '우울', '마음', '달래', '노래', '모음'],
#  ['청량감', '여름', '저격', '댄스곡'],
#  ['꽃길', '입맞춤', '달콤', '분위기', '장르불문', '분위기', '띄우'],
#  ['클럽', '일', '렉트로닉'],
#  ['그래미', '어', '워', '즈', '컨', '츄리', '가', '스펠', '부문', '후보곡'],
#  ['가슴', '뭉클'],
#  [''],
#  ['금요일', '비', '오', '그치', '날씨', '이상'],
#  ['응팔', '모음', '집'],
#  ['아무', '좋아하', '노', '래'],
#  ['듣', '곡', '없', '같', '밤', '듣', '곡'],
#  ['살'],
#  ['리드', '미컬'],
#  ['목요일', '그냥', '왠지', '싫'],
#  ['감성', '있', '는밤'],
#  ['인생', '바꾸', '있', '시점', '너', '위로', '계속', '추가'],
#  ['커피', '마시', '조용히', '듣', '좋', '노래'],
#  ['다양', '맛', '찾아오', '빨간', '고추'],
#  ['요즘', '푹', '빠지', '곡'],
#  ['아련', '옛', '드라마', '모', '음'],
#  ['사랑', '혹은', '슬프', '이별', '가슴', '남기'],
#  ['조금', '선선', '밤', '걷', '듣', '좋', '노래'],
#  ['진', '토닉', '함께', '듣', '음악'],
#  [''],
#  ['아침', '활력', '위하', '재즈'],
#  ['듣', '좋', '뉴에이', '지', '음악'],
#  ['좋'],
#  ['이소라', '명곡', '집'],
#  ['멜론', '좋', '수', '이상', '곡들'],
#  ['올', '여름', '일렉', '파도', '밀려오'],
#  ['호', '주차트'],
#  ['무덥', '여름', '청량감', '더', '플레이리스트'],
#  ['새벽', '듣', '잠', '잘', '오', '노래'],
#  ['오래', '드라마'],
#  ['리드미', '컬', '느낌', '좋', '느낌'],
#  ['나', '날', '보내', '때'],
#  ['ఇ', '벅차', '오르', '숨', '여돌', '명곡'],
#  ['요요마곡'],
#  ['워너', '재결성'],
#  ['멜로디', '포레', '스', '트', '캠프', '주요', '라인업'],
#  ['루키', '행보', '기대', '신예', '아티스트'],
#  ['사랑', '왠지', '끌리', '노래'],
#  ['완전', '감동', '음악'],
#  ['봄', '오'],
#  ['달달'],
#  ['사랑', '이', '함께', '있'],
#  ['마약', '같', '씨잼', '싱잉랩'],
#  ['혼자', '시간', '편안', '무드', '베드룸', '팝'],
#  ['가슴', '전율', '일', '렉', '트로니카', '세계'],
#  [''],
#  ['힙잘알', '되', '주차', '비프', '리'],
#  ['공부', '때', '듣', '편안', '음악'],
#  ['혼자', '끄덕끄덕'],
#  ['따뜻', '봄저녘', '듣', '힐', '링가득찬', '음색'],
#  ['가사', '꼭', '나', '얘기'],
#  ['아이돌', '숨', '명곡'],
#  ['태교', '음악', '사랑', '우리', '아이', '위하', '자장', '가음악'],
#  ['여름', '휴가', '가', '차안', '듣', '좋', '노래'],
#  ['나', '고막', '책임', '여성', '솔로', '아티스트'],
#  ['잃'],
#  ['뉴에', '지', '신', '곡', '모음집'],
#  ['덥', '여름', '그대', '시원', '노래'],
#  ['감성보컬', '알', '앤비', '좋', '밤', '되'],
#  [''],
#  ['진정', '울림'],
#  ['오늘', '서', '글', '픔'],
#  ['부드럽', '뉴에이지', '듣', '쉬'],
#  ['크리스마스', '앞두', '아이돌', '겨울', '노래'],
#  ['내', '좋아하', '래퍼', '지심'],
#  ['달달', '터지', '외로움', '터', '지', '같', '인디음악'],
#  [''],
#  ['마', '성', '목소리', '수록', '곡'],
#  ['비', '커피', '추억', '잔', '잔', '노', '래'],
#  ['사랑', '관하', '설', '렘', '가득', '피아노', '힐링', '음악'],
#  ['후', '입김', '나오', '시작', '춥', '겨울', '따스', '노래', '듣', '이겨내'],
#  ['한강', '바라보', '릴렉스'],
#  [''],
#  ['크리스마스', '맞이'],
#  [''],
#  ['여유', '필요', '당신', '건네', '감미', '재즈', '팝'],
#  [''],
#  ['알', '말듯', '네', '마음', '궁금'],
#  ['비', '오', '날', '듣', '필청곡'],
#  ['인디음악', '소화', '가장', '쉽', '방법'],
#  ['거장', '클린트', '이스트우드', '감독', '영화', '음악', '세계'],
#  ['이소라', '두', '프로', '포즈'],
#  ['볼빨', '간사춘기', '안지영', '생일'],
#  [''],
#  ['무더위', '한', '날리'],
#  ['나', '애곡', '모음'],
#  ['숨', '명곡', '대신', '찾아', '리'],
#  ['모두', '다', '알', '한', '다', '시듣', '노래'],
#  ['사랑', '받', '곡모음'],
#  ['빌보드차트', '취향', '저격'],
#  ['파워', '풀', '가창력', '소유자', '내한', '예상', '세트리스트'],
#  ['이', '정도', '재즈', '충분'],
#  ['여름', '밤', '바람', '불', '카페', '듣', '노래'],
#  ['록', '춤', '추', '있'],
#  ['당신', '맘', '밤', '적시', '감성', '힙합'],
#  ['겁크', '파이', '팅'],
#  ['국내', '힙스타일'],
#  ['고개', '까닥', '까닥', '듣', '좋', '노래'],
#  ['디제', '이', '플레이'],
#  ['워너', '에센셜', '제스', '글린'],
#  ['무도가', '요제', '후보'],
#  ['나', '중', '병', '락', '심취'],
#  ['중독', '강', '노래'],
#  ['연애', '세포', '자극', '달달', '남녀', '듀엣', '곡'],
#  ['랩', '모르', '사람', '재즈', '들'],
#  [''],
#  ['퇴근길', '발', '라드', '취하'],
#  ['사랑', '가득', '노래'],
#  ['락발라드'],
#  ['그루', '브', '넘치'],
#  ['오래', '최신', '알', '사람', '알'],
#  ['음악', '세계', '기말'],
#  ['이갈룡폴더'],
#  ['어쿠스틱', '달다랗', '노래'],
#  [''],
#  ['겨울', '봄', '사이', '어디'],
#  ['가을', '발라드', '감성', '샷추가', '음색', '시', '럽추', '하', '듣어'],
#  ['시대', '차별', '없', '인싸곡', '노래', '모음'],
#  ['네', '오', '하', '카페', '너', '너'],
#  ['위하', '노래', '선'],
#  ['사랑', '이름', '교집합'],
#  ['마음', '안정', '클래식'],
#  ['늦', '봄', '이별후'],
#  ['분위기', '끝나', '노래'],
#  ['나', '감성', '음악'],
#  ['조용히', '심연', '깊이', '울리', '여', '운'],
#  ['리', '메이', '크', '드라마'],
#  ['차타', '달리', '때'],
#  ['기억', '망각', '이동진', '의', '꿈', '다방', '라디'],
#  [''],
#  ['정미', '애', '팬분', '스밍', '용', '기초교류'],
#  ['비', '어울리', '감성', '힙합', '드랍', '더', '비트'],
#  ['매장', '쓰', '수', '있', '신나', '음악'],
#  ['드라마', '속', '분위기', '녹아들'],
#  ['덥', '지', '마음', '시원'],
#  ['이별', '하', '울', '되'],
#  ['푸르', '바다', '남자', '이별', '이야기'],
#  ['특별', '주말', '특별'],
#  ['음악', '오타쿠', '분위기', '오타쿠', '듣', '위하'],
#  ['사로잡', '패밀리', '그룹'],
#  ['봄', '듣', '좋', '상큼', '달달', '경쾌', '발랄', '음악'],
#  ['무슨', '뜻', '숫자', '제목', '노래'],
#  ['안예', '곡'],
#  ['멜로디'],
#  ['두', '도란도', '란'],
#  ['여름', '댄스'],
#  ['이노래', '그때', '그', '노래'],
#  ['제이팝', '여왕', '하마사키', '아', '유', '미'],
#  ['클럽', '타', '자', '보아일랜드', '루루루', '진', '달', '래', '밴드', '문패트롤'],
#  ['신', '나', '크리스', '마스'],
#  ['미국차트'],
#  ['가을', '머금', '카페', '뮤직'],
#  ['새롭', '물결', '얼터너티브'],
#  ['오지', '지리', '팝', '락각', '겨울', '여행'],
#  ['어디', '들어보', '없', '재즈', '모음'],
#  ['트와이스', '일본', '타이틀', '곡', '모음'],
#  ['외국', '힙합'],
#  ['느낌', '있', '음악'],
#  ['눈물', '나', '얘기'],
#  ['베리베리', '해피', '메리', '크리스마스'],
#  ['태교', '좋', '노래'],
#  ['뽀글뽀글', '노래', '듣어'],
#  [''],
#  ['이', '노래', '가을', '가을', '느끼', '시작', '때', '듣', '노래'],
#  ['아버지', '어머니', '바치', '노래'],
#  ['나', '위로', '필요'],
#  ['달달', '재즈', '플레이리스트'],
#  ['감성', '힙합'],
#  ['향기', '가득', '매장', '위하', '뉴에이', '지'],
#  ['신', '나', '댄스곡'],
#  ['혼자', '시간', '채우', '따스', '팝'],
#  ['이별후', '마음', '정리', '위하', '감성', '음악'],
#  ['하루', '마무리', '듣', '편안', '곡'],
#  ['역대', '쇼미더머니', '음원', '모음'],
#  ['푸르', '바', '다', '의전설', '도깨비'],
#  ['설', '레임', '인디사운드'],
#  ['감각', '트렌디', '유니크', '노래'],
#  ['잔잔', '듣', '좋', '곡'],
#  ['올드', '힙합'],
#  ['가사', '은근히'],
#  ['발라드', '모음'],
#  ['겨울', '감성', '진하', '묻어나', '포근', '보이', '스라', '떼', '로맨', '틱', '멜로디'],
#  ['시원', '가을', '밤', '드라이브', '즐기', '듣', '음악'],
#  ['로보트', '주인공', '노래'],
#  ['새벽길', '잔잔', '감성', '리스트'],
#  ['하', '너무', '아깝', '명곡'],
#  ['걸', '그룹', '아이돌', '히트곡', '모음'],
#  ['시대', '차트', '국내', '차트'],
#  ['비투비', '각', '앨범', '좋', '수록', '곡'],
#  ['디', '사', '이', '저', '베이비'],
#  ['비', '오', '날', '어울리', '잔잔', '느끼'],
#  ['너무', '춥', '날씨', '감성', '발라드', '따뜻'],
#  ['애니메이션', '명곡'],
#  ['학교', '가', '길', '기분', '좋', '살랑', '살랑', '힙한', '인디', '노래'],
#  [''],
#  ['젊음', '가요제', '입상곡'],
#  ['여름', '드라이브', '여행', '때', '듣', '좋', '상큼', '발랄', '신', '나', '노래', '업뎃', '수정'],
#  ['유럽', '음악', '모음'],
#  ['늦', '밤', '나', '감성', '깨우', '취향', '저격', '음악'],
#  ['내', '요즘', '듣', '노래', '같이', '듣'],
#  ['힘들', '때', '혼자', '듣', '좋', '음악'],
#  ['미국식', '토종', '힙합'],
#  ['도입', '부', '사로잡'],
#  ['아무', '생각', '없이', '듣', '좋', '노래'],
#  ['슬프', '때', '함께', '울', '힙합'],
#  ['마음', '맑', '힐링', '뉴에이', '지'],
#  ['러브라', '추리게임', '하트시그널', '시즌'],
#  ['한', '듣', '보', '오래전', '팝송', '바로', '그거'],
#  ['이국', '느낌', '좋', '음악'],
#  ['웨딩', '듣', '하', '결혼', '웨', '딩', '송'],
#  ['성'],
#  ['머릿속', '맴돌', '멜로디', '중독', '짱'],
#  ['라이브아', '미', '주', '플레이리스트'],
#  ['나', '알', '리스', '트'],
#  ['봄', '날', '멜', '랑콜리아', '색다르', '인디'],
#  ['상큼', '큼', '공감', '노래'],
#  ['멜론', '인기곡', '가요'],
#  ['렬루', '곡', '탄'],
#  ['댄스2'],
#  ['요즘', '많이', '듣', '곡'],
#  ['잠자', '듣', '좋', '퓨전', '국악'],
#  ['흐리', '가을', '하늘', '쓰', '음악', '편지'],
#  ['심쿵', '곡', '모음'],
#  [''],
#  ['슬프', '이별', '발라드', '노래', '곡'],
#  ['함께', '듣', '노래'],
#  ['일자', '싱글', '차트'],
#  ['잔차', '라이딩', '음악'],
#  ['나', '새봄'],
#  ['운동', '끝', '록', '음악', '상쾌', '홈트'],
#  ['클래식', '음악', '매력', '속'],
#  ['어쩌면', '우리', '첫', '클래식'],
#  ['라디오', '청취자', '오랜', '사랑', '받', '대중가요'],
#  ['오페라', '아버지', '베르디', '명작'],
#  ['명곡', '리메이크'],
#  ['첫', '내한', '예상', '세트리스트'],
#  [''],
#  ['크리스마스', '노래', '퐁당', '빠져'],
#  ['이런', '어쿠스틱', '분위기', '있', '팝송', '추천', '채우'],
#  ['듣', '카톡', '프로필뮤직', '바꾸', '봄감', '가득', '노래'],
#  ['나른', '시간', '채우', '달콤', '뉴에이', '지'],
#  ['한', '주말', '함께', '뮤직', '수시업'],
#  ['혹시', '오늘', '하', '우울'],
#  ['그냥', '틀', '좋', '힙합', '팝'],
#  ['여름', '바다'],
#  ['따뜻', '카페', '듣', '재즈', '캐롤', '연주곡'],
#  ...]

# %%
len(morphs)
# Out:
# 115071

# %%
morphs[0]
# Out:
# ['여행', '같', '음악']
